# %% [markdown]
# # VNA Tools training class
# Written by aws 10/2016

# %% [markdown]
# ## Introduction (R and S)
# By Herald Jaeger from Rohde and Schwarz Germany
# Senior Metrologist
# 1. Rodde and scwharz produces test equipment and standards
# 2. NMI's establish
#
# ## Introduction (METAS)
# By Juerg
# 1. Began in 2006 based on Round Robin of Load from NMI's
# 2. Pin depth variation caused uncert greater than NMI estimations
# 3. Nitch established for coaxial uncertainty

# %% [markdown]
# ## Personal Introductions
# 1. Lots of R&S personel looking to change ripple method for 50Ghz
# 2. Maury Microwave looking for better measurements for standards and instruments produced
# 3. Bionetics

# %% [markdown]
# ## METAS Introduction
# ## VNA Tools

# %% [markdown]
# ## VNA Tools Basics
# 1. Written in C#
# 2. Runs on MS windows
# 3. Supported VNAs
#     a. Keysight ENA and PNA models
#     b. Vector Stae
#     c. Rohde and Schwarz ZV*
#     d. Copper Mountain
#  4. VNA
#  5. uNCLIB
#
#  ### Philo
#
#  1. All values are done outside of VNA
#  2. Flexibility  (different calibrations on same data)
#  3. Measurement Journal

# %% [markdown]
# # Metas.UncLib
# ## Concepts in Meas Uncert prop acording to ISO GUM
# ### Basic
# 1. Input Quantities uncorr
# 2. Measurement Model
# 3. Output (partial der)
# 4. Expanded meas uncert
# ### Multivariate
# 1. Uncert Matrix
# 2. Lin. Uncert Propagation
# 3. Expanded Meas Uncertain (multidim)
#
# ## Metas.Unclib
# + Multdim Uncertain Calc
# + Advanced Math ( Complex, Vector matrix)
#
#
# + Does not have models
# + No GUI
# + Produce Fancy Output
#
# GUM Tree Concept
# Automatic Differentation ( Calculate Derivatives to machine Precision)
# Object Oriented Implementation

# %% [markdown]
# ## Sources of Uncertainty in VNA
# 1. Noise Floor and Noise Trace
# 2. Linearity
# 3. Drift
# 4. Cable Stability
# 5. Connector Repeatability
# 6. Calibration Standard Definitions

# %% [markdown]
# # VNA Setup
# 1. Check Communication to VNA and Resource Name
# 2. Create New VNA Device in Database tab
# 3. Add some default values
# 4. Choose VNA types
# 5. Test communication
#
# # Cable Selection
# 1. Go to Cable tab in database
# 2. Select standard set of cables and define them
# 3.
#
# # Measurement Setup
# 1. Measurement Journal
# 2.

# %%
import sys
sys.path.append(r'C:\Program Files (x86)\METAS\Metas.Vna.Tools')
import clr
clr.AddReference('System.Windows.Forms')
clr.AddReference('Metas.Vna.Tools')
clr.AddReference('Metas.Vna.Data')
clr.AddReference('Metas.Vna.Misc')
from System import Array
from System.Threading import Thread
from System.Windows.Forms import MessageBox
from Metas.Vna.Tools import Script
from Metas.Vna.Misc import DirectoryTools
from Metas.Vna.Misc import StepAttenuatorTools
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:9: DeprecationWarning:
# The module was found, but not in a referenced namespace.
# Implicit loading is deprecated. Please use clr.AddReference("System.Threading").
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:10: DeprecationWarning:
# The module was found, but not in a referenced namespace.
# Implicit loading is deprecated. Please use clr.AddReference("System.Windows").

# %%
help(Script)
# Out:
# Help on class Script in module Metas.Vna.Tools:
#
# class Script(30923, Culture=neutral, PublicKeyToken=3694dea3dd97db1a]])
#  |  Void .ctor()
#  |  Void .ctor(System.String)
#  |  Void .ctor(System.String, System.String)
#  |
#  |  Method resolution order:
#  |      Script
#  |      30923, Culture=neutral, PublicKeyToken=3694dea3dd97db1a]]
#  |      System.Object
#  |      __builtin__.object
#  |
#  |  Methods defined here:
#  |
#  |  __call__(...)
#  |      x.__call__(...) <==> x(...)
#  |
#  |  __cmp__(...)
#  |      x.__cmp__(y) <==> cmp(x,y)
#  |
#  |  __delitem__(...)
#  |      x.__delitem__(y) <==> del x[y]
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __hash__(...)
#  |      x.__hash__() <==> hash(x)
#  |
#  |  __init__(...)
#  |      x.__init__(...) initializes x; see help(type(x)) for signature
#  |
#  |  __iter__(...)
#  |      x.__iter__() <==> iter(x)
#  |
#  |  __setitem__(...)
#  |      x.__setitem__(i, y) <==> x[i]=y
#  |
#  |  __str__(...)
#  |      x.__str__() <==> str(x)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  Overloads
#  |
#  |  __overloads__
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __new__ = <built-in method __new__ of CLR Metatype object>
#  |      T.__new__(S, ...) -> a new object with type S, a subtype of T
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from 30923, Culture=neutral, PublicKeyToken=3694dea3dd97db1a]]:
#  |
#  |  Add
#  |      Void Add(System.String, System.String, System.String)
#  |
#  |  AddDCPoint1P
#  |      Void AddDCPoint1P(System.String, Double, Double, System.String)
#  |
#  |  AddDCPoint2P
#  |      Void AddDCPoint2P(System.String, Double, Double, Double, Double, Double, Double, Double, Double, System.String)
#  |
#  |  Cascade
#  |      Void Cascade(System.String[], System.String)
#  |      Void Cascade(System.String, System.String, System.String)
#  |
#  |  ChangePortAssignment
#  |      Void ChangePortAssignment(System.String, System.String, System.String)
#  |
#  |  ChangeZr
#  |      Void ChangeZr(System.String, Double, Double, System.String)
#  |
#  |  CircleFit
#  |      Void CircleFit(System.String, System.String)
#  |
#  |  ComputeCalibration
#  |      Void ComputeCalibration(System.String, System.String)
#  |
#  |  ComputeErrorCorrection
#  |      Void ComputeErrorCorrection(System.String)
#  |      Void ComputeErrorCorrection(System.String, System.String, System.String, System.String, System.String)
#  |
#  |  Decascade
#  |      Void Decascade(System.String, System.String, System.String)
#  |
#  |  Divide
#  |      Void Divide(System.String, System.String, System.String)
#  |
#  |  Interpolation
#  |      Void Interpolation(System.String, Double[], System.String)
#  |      Void Interpolation(System.String, System.String, System.String)
#  |
#  |  LoadCalibration
#  |      Metas.Vna.Calibration.ICalibration`1[Metas.UncLib.LinProp.UncNumber] LoadCalibration(System.String)
#  |
#  |  LoadFileCalConfig
#  |      Metas.Vna.Calibration.Config.FileCalConfig LoadFileCalConfig(System.String)
#  |
#  |  LoadFileErrorCorrConfig
#  |      Metas.Vna.Calibration.Config.FileErrorCorrConfig LoadFileErrorCorrConfig(System.String)
#  |
#  |  LoadFileSlidingLoadConfig
#  |      Metas.Vna.Calibration.Config.FileSlidingLoadConfig LoadFileSlidingLoadConfig(System.String)
#  |
#  |  LoadJournal
#  |      Metas.Vna.Journal.Journal LoadJournal(System.String)
#  |
#  |  LoadSParamData
#  |      Metas.Vna.Data.SParamData`1[Metas.UncLib.LinProp.UncNumber] LoadSParamData(System.String)
#  |
#  |  Mean
#  |      Void Mean(System.String, System.String)
#  |
#  |  Merge
#  |      Void Merge(System.String, System.String, Double, System.String)
#  |
#  |  Multiply
#  |      Void Multiply(System.String, System.String, System.String)
#  |
#  |  NewJournal
#  |      Metas.Vna.Journal.Journal NewJournal()
#  |
#  |  OpenECal
#  |      Metas.Instr.Driver.ECal.IECal OpenECal(System.String, System.String)
#  |
#  |  OpenSwitch
#  |      Metas.Instr.Driver.Switch.ISwitch OpenSwitch(System.String, System.String)
#  |
#  |  OpenVna
#  |      Metas.Instr.Driver.Vna.IVna OpenVna(System.String)
#  |      Metas.Instr.Driver.Vna.IVna OpenVna(System.String, System.String)
#  |
#  |  RemoveDependencies
#  |      Void RemoveDependencies(System.String, System.String)
#  |      Void RemoveDependencies(System.String, System.String, System.Guid)
#  |
#  |  RemoveDependenciesFromDataSet
#  |      Void RemoveDependenciesFromDataSet(System.String, System.String)
#  |      Void RemoveDependenciesFromDataSet(System.String, System.String, System.Guid, System.String)
#  |
#  |  RemoveDependenciesFromDataSet2
#  |      Void RemoveDependenciesFromDataSet2(System.String, System.String)
#  |      Void RemoveDependenciesFromDataSet2(System.String, System.String, System.Guid, System.String)
#  |
#  |  Reverse
#  |      Void Reverse(System.String, System.String)
#  |
#  |  RootPath
#  |
#  |  RootPathDatabase
#  |
#  |  RootPathDbCables
#  |
#  |  RootPathDbCalibrationStandards
#  |
#  |  RootPathDbConnectors
#  |
#  |  RootPathDbVnaDevices
#  |
#  |  SaveCalibration
#  |      Void SaveCalibration(System.String, Metas.Vna.Calibration.ICalibration`1[Metas.UncLib.LinProp.UncNumber])
#  |
#  |  SaveCalibrationErrorTerms
#  |      Void SaveCalibrationErrorTerms(System.String, System.String)
#  |
#  |  SaveCalibrationSwitchTerms
#  |      Void SaveCalibrationSwitchTerms(System.String, System.String)
#  |
#  |  SaveCalibrationSwitchedErrorTerms
#  |      Void SaveCalibrationSwitchedErrorTerms(System.String, System.String)
#  |
#  |  SaveFileCalConfig
#  |      Void SaveFileCalConfig(System.String, Metas.Vna.Calibration.Config.FileCalConfig)
#  |
#  |  SaveFileErrorCorrConfig
#  |      Void SaveFileErrorCorrConfig(System.String, Metas.Vna.Calibration.Config.FileErrorCorrConfig)
#  |
#  |  SaveFileSlidingLoadConfig
#  |      Void SaveFileSlidingLoadConfig(System.String, Metas.Vna.Calibration.Config.FileSlidingLoadConfig)
#  |
#  |  SaveJournal
#  |      Void SaveJournal(System.String, Metas.Vna.Journal.Journal)
#  |
#  |  SaveSParamData
#  |      Void SaveSParamData(System.String, Metas.Vna.Data.SParamData`1[Metas.UncLib.LinProp.UncNumber])
#  |
#  |  ShowWorkerDialog
#  |
#  |  Subset
#  |      Void Subset(System.String, System.String, System.String)
#  |
#  |  SubsetAndChangePortAssignment
#  |      Void SubsetAndChangePortAssignment(System.String, System.String, System.String)
#  |
#  |  Subtract
#  |      Void Subtract(System.String, System.String, System.String)
#  |
#  |  get_RootPath
#  |      System.String get_RootPath()
#  |
#  |  get_RootPathDatabase
#  |      System.String get_RootPathDatabase()
#  |
#  |  get_RootPathDbCables
#  |      System.String get_RootPathDbCables()
#  |
#  |  get_RootPathDbCalibrationStandards
#  |      System.String get_RootPathDbCalibrationStandards()
#  |
#  |  get_RootPathDbConnectors
#  |      System.String get_RootPathDbConnectors()
#  |
#  |  get_RootPathDbVnaDevices
#  |      System.String get_RootPathDbVnaDevices()
#  |
#  |  get_ShowWorkerDialog
#  |      Boolean get_ShowWorkerDialog()
#  |
#  |  set_RootPath
#  |      Void set_RootPath(System.String)
#  |
#  |  set_RootPathDatabase
#  |      Void set_RootPathDatabase(System.String)
#  |
#  |  set_ShowWorkerDialog
#  |      Void set_ShowWorkerDialog(Boolean)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from System.Object:
#  |
#  |  Equals
#  |      Boolean Equals(System.Object)
#  |      Boolean Equals(System.Object, System.Object)
#  |
#  |  Finalize
#  |      Void Finalize()
#  |
#  |  GetHashCode
#  |      Int32 GetHashCode()
#  |
#  |  GetType
#  |      System.Type GetType()
#  |
#  |  MemberwiseClone
#  |      System.Object MemberwiseClone()
#  |
#  |  ReferenceEquals
#  |      Boolean ReferenceEquals(System.Object, System.Object)
#  |
#  |  ToString
#  |      System.String ToString()
