# %%
from pyMez import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 4.544 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.814 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# It took 14.657 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# It took 0.015 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.481 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.07 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# It took 2.83 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.025 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.019 s to import Code.Utils.Names
# It took 23.455 s to import all of the active modules

# %%
from pyMez.Code.DataHandlers.XMLModels import *

# %%
new_db=FileRegister()

# %%
new_db.add_entry(r"C:\Share\HarmonicWaveletTransform_1.pdf")

# %%
print new_db
# Out:
# <File_Registry><File Date="2018-09-01T04:44:27.906000" Host="672PIF-AS1.campus.nist.gov" Id="192.168.1.2.11.11.21" Type="Ordinary" URL="file:C:/Share/HarmonicWaveletTransform_1.pdf"/></File_Registry>

# %%
new_db=FileRegister()
new_db.add_entry(r"C:\Share\HarmonicWaveletTransform_1.pdf")
new_db.add_tree(r"C:\Share\SpectralEntropy")

# %%
new_db.add_tree(r"C:\Share\SpectralEntropy")
# Out:
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21'}
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21'}
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21'}
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21'}
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21'}
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21'}
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22'}
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22'}
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22'}
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23'}
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23'}
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23'}
# {'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24'}
# {'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24'}
# {'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24'}
# {'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_1.png': '192.168.1.2.11.11.12.215', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_1.png': '192.168.1.2.11.11.12.215', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_1.png': '192.168.1.2.11.11.12.215', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_1.png': '192.168.1.2.11.11.12.215', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26'}
# ...
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_3.png': '192.168.1.2.11.11.12.238', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.235', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.232', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_6.png': '192.168.1.2.11.11.12.241', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/LogLogentropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.222', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.237', 'file:C:/Share/SpectralEntropy/SE95_GaussainFit.png': '192.168.1.2.11.11.12.229', 'file:C:/Share/SpectralEntropy/SE85_LorentzianFit.png': '192.168.1.2.11.11.12.226', 'file:C:/Share/SpectralEntropy/NoNoise.png': '192.168.1.2.11.11.12.223', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214', 'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_1.png': '192.168.1.2.11.11.12.217', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/SpectralEntropy/SE_Normal_Vs_SampleSize.png': '192.168.1.2.11.11.12.230', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_3.png': '192.168.1.2.11.11.12.234', 'file:C:/Share/SpectralEntropy/loglogentropyvssignalstrength.png': '192.168.1.2.11.11.12.221', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.239', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/guassian_withLine_triangularNoise_2.png': '192.168.1.2.11.11.12.219', 'file:C:/Share/SpectralEntropy/guassian_withLine_uniformNoise_2.png': '192.168.1.2.11.11.12.220', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_1.png': '192.168.1.2.11.11.12.215', 'file:C:/Share/SpectralEntropy/Se94_Gaussian_ofSE91Lorentzian.png': '192.168.1.2.11.11.12.228', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/SE64PowerFitOfSE91Lorentzian.png': '192.168.1.2.11.11.12.225', 'file:C:/Share/SpectralEntropy/Se91LorentzianFit.png': '192.168.1.2.11.11.12.227', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26', 'file:C:/Share/SpectralEntropy/Se45PowerFit.png': '192.168.1.2.11.11.12.224', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_2.png': '192.168.1.2.11.11.12.218', 'file:C:/Share/SpectralEntropy/SignalPlusNoiseSE93.png': '192.168.1.2.11.11.12.231', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.233', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_2.png': '192.168.1.2.11.11.12.216', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_5.png': '192.168.1.2.11.11.12.240', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_7.png': '192.168.1.2.11.11.12.242', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.236', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_3.png': '192.168.1.2.11.11.12.238', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.235', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.232', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_6.png': '192.168.1.2.11.11.12.241', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/LogLogentropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.222', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.237', 'file:C:/Share/SpectralEntropy/SE95_GaussainFit.png': '192.168.1.2.11.11.12.229', 'file:C:/Share/SpectralEntropy/SE85_LorentzianFit.png': '192.168.1.2.11.11.12.226', 'file:C:/Share/SpectralEntropy/NoNoise.png': '192.168.1.2.11.11.12.223', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214', 'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_1.png': '192.168.1.2.11.11.12.217', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/SpectralEntropy/SE_Normal_Vs_SampleSize.png': '192.168.1.2.11.11.12.230', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_3.png': '192.168.1.2.11.11.12.234', 'file:C:/Share/SpectralEntropy/loglogentropyvssignalstrength.png': '192.168.1.2.11.11.12.221', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.239', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/guassian_withLine_triangularNoise_2.png': '192.168.1.2.11.11.12.219', 'file:C:/Share/SpectralEntropy/guassian_withLine_uniformNoise_2.png': '192.168.1.2.11.11.12.220', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_1.png': '192.168.1.2.11.11.12.215', 'file:C:/Share/SpectralEntropy/Se94_Gaussian_ofSE91Lorentzian.png': '192.168.1.2.11.11.12.228', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/SE64PowerFitOfSE91Lorentzian.png': '192.168.1.2.11.11.12.225', 'file:C:/Share/SpectralEntropy/Se91LorentzianFit.png': '192.168.1.2.11.11.12.227', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26', 'file:C:/Share/SpectralEntropy/Se45PowerFit.png': '192.168.1.2.11.11.12.224', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_2.png': '192.168.1.2.11.11.12.218', 'file:C:/Share/SpectralEntropy/SignalPlusNoiseSE93.png': '192.168.1.2.11.11.12.231', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.233', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_2.png': '192.168.1.2.11.11.12.216', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_5.png': '192.168.1.2.11.11.12.240', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_7.png': '192.168.1.2.11.11.12.242', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.236', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_3.png': '192.168.1.2.11.11.12.238', 'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.235', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.232', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_6.png': '192.168.1.2.11.11.12.241', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/LogLogentropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.222', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.237', 'file:C:/Share/SpectralEntropy/SE95_GaussainFit.png': '192.168.1.2.11.11.12.229', 'file:C:/Share/SpectralEntropy/SE85_LorentzianFit.png': '192.168.1.2.11.11.12.226', 'file:C:/Share/SpectralEntropy/NoNoise.png': '192.168.1.2.11.11.12.223', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214', 'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_1.png': '192.168.1.2.11.11.12.217', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/SpectralEntropy/SE_Normal_Vs_SampleSize.png': '192.168.1.2.11.11.12.230', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_3.png': '192.168.1.2.11.11.12.234', 'file:C:/Share/SpectralEntropy/loglogentropyvssignalstrength.png': '192.168.1.2.11.11.12.221', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.239', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/guassian_withLine_triangularNoise_2.png': '192.168.1.2.11.11.12.219', 'file:C:/Share/SpectralEntropy/guassian_withLine_uniformNoise_2.png': '192.168.1.2.11.11.12.220', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_1.png': '192.168.1.2.11.11.12.215', 'file:C:/Share/SpectralEntropy/Se94_Gaussian_ofSE91Lorentzian.png': '192.168.1.2.11.11.12.228', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/SE64PowerFitOfSE91Lorentzian.png': '192.168.1.2.11.11.12.225', 'file:C:/Share/SpectralEntropy/Se91LorentzianFit.png': '192.168.1.2.11.11.12.227', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26', 'file:C:/Share/SpectralEntropy/Se45PowerFit.png': '192.168.1.2.11.11.12.224', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_2.png': '192.168.1.2.11.11.12.218', 'file:C:/Share/SpectralEntropy/SignalPlusNoiseSE93.png': '192.168.1.2.11.11.12.231', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.233', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_2.png': '192.168.1.2.11.11.12.216', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_5.png': '192.168.1.2.11.11.12.240', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_7.png': '192.168.1.2.11.11.12.242', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.236', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28'}
# {'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_3.png': '192.168.1.2.11.11.12.238', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.235', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.232', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_6.png': '192.168.1.2.11.11.12.241', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25', 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211', 'file:C:/Share/SpectralEntropy/LogLogentropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.222', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.237', 'file:C:/Share/SpectralEntropy/SE95_GaussainFit.png': '192.168.1.2.11.11.12.229', 'file:C:/Share/SpectralEntropy/SE85_LorentzianFit.png': '192.168.1.2.11.11.12.226', 'file:C:/Share/SpectralEntropy/NoNoise.png': '192.168.1.2.11.11.12.223', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214', 'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_1.png': '192.168.1.2.11.11.12.217', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212', 'file:C:/Share/SpectralEntropy/SE_Normal_Vs_SampleSize.png': '192.168.1.2.11.11.12.230', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_3.png': '192.168.1.2.11.11.12.234', 'file:C:/Share/SpectralEntropy/loglogentropyvssignalstrength.png': '192.168.1.2.11.11.12.221', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.239', 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210', 'file:C:/Share/SpectralEntropy/guassian_withLine_triangularNoise_2.png': '192.168.1.2.11.11.12.219', 'file:C:/Share/SpectralEntropy/guassian_withLine_uniformNoise_2.png': '192.168.1.2.11.11.12.220', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_1.png': '192.168.1.2.11.11.12.215', 'file:C:/Share/SpectralEntropy/Se94_Gaussian_ofSE91Lorentzian.png': '192.168.1.2.11.11.12.228', 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24', 'file:C:/Share/SpectralEntropy/SE64PowerFitOfSE91Lorentzian.png': '192.168.1.2.11.11.12.225', 'file:C:/Share/SpectralEntropy/Se91LorentzianFit.png': '192.168.1.2.11.11.12.227', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22', 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26', 'file:C:/Share/SpectralEntropy/Se45PowerFit.png': '192.168.1.2.11.11.12.224', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213', 'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_2.png': '192.168.1.2.11.11.12.218', 'file:C:/Share/SpectralEntropy/SignalPlusNoiseSE93.png': '192.168.1.2.11.11.12.231', 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.233', 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_2.png': '192.168.1.2.11.11.12.216', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_5.png': '192.168.1.2.11.11.12.240', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_7.png': '192.168.1.2.11.11.12.242', 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29', 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.236', 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28'}

# %%
new_db.Id_dictionary
# Out:
# {'file:C:/Share/HarmonicWaveletTransform_1.pdf': '192.168.1.2.11.11.21',
#  'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png': '192.168.1.2.11.11.12.21',
#  'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png': '192.168.1.2.11.11.12.24',
#  'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png': '192.168.1.2.11.11.12.25',
#  'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.26',
#  'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.27',
#  'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.28',
#  'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png': '192.168.1.2.11.11.12.29',
#  'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png': '192.168.1.2.11.11.12.210',
#  'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png': '192.168.1.2.11.11.12.211',
#  'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png': '192.168.1.2.11.11.12.212',
#  'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png': '192.168.1.2.11.11.12.213',
#  'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png': '192.168.1.2.11.11.12.214',
#  'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_1.png': '192.168.1.2.11.11.12.215',
#  'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_2.png': '192.168.1.2.11.11.12.216',
#  'file:C:/Share/SpectralEntropy/LogLogentropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.222',
#  'file:C:/Share/SpectralEntropy/NoNoise.png': '192.168.1.2.11.11.12.223',
#  'file:C:/Share/SpectralEntropy/SE64PowerFitOfSE91Lorentzian.png': '192.168.1.2.11.11.12.225',
#  'file:C:/Share/SpectralEntropy/SE85_LorentzianFit.png': '192.168.1.2.11.11.12.226',
#  'file:C:/Share/SpectralEntropy/SE95_GaussainFit.png': '192.168.1.2.11.11.12.229',
#  'file:C:/Share/SpectralEntropy/SE_Normal_Vs_SampleSize.png': '192.168.1.2.11.11.12.230',
#  'file:C:/Share/SpectralEntropy/Se45PowerFit.png': '192.168.1.2.11.11.12.224',
#  'file:C:/Share/SpectralEntropy/Se91LorentzianFit.png': '192.168.1.2.11.11.12.227',
#  'file:C:/Share/SpectralEntropy/Se94_Gaussian_ofSE91Lorentzian.png': '192.168.1.2.11.11.12.228',
#  'file:C:/Share/SpectralEntropy/SignalPlusNoiseSE93.png': '192.168.1.2.11.11.12.231',
#  'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.232',
#  'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.233',
#  'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_3.png': '192.168.1.2.11.11.12.234',
#  'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.235',
#  'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_1.png': '192.168.1.2.11.11.12.236',
#  'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_2.png': '192.168.1.2.11.11.12.237',
#  'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_3.png': '192.168.1.2.11.11.12.238',
#  'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_4.png': '192.168.1.2.11.11.12.239',
#  'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_5.png': '192.168.1.2.11.11.12.240',
#  'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_6.png': '192.168.1.2.11.11.12.241',
#  'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_7.png': '192.168.1.2.11.11.12.242',
#  'file:C:/Share/SpectralEntropy/VisibleEffectOnEntropy.png': '192.168.1.2.11.11.12.243',
#  'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png': '192.168.1.2.11.11.12.22',
#  'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png': '192.168.1.2.11.11.12.23',
#  'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_1.png': '192.168.1.2.11.11.12.217',
#  'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_2.png': '192.168.1.2.11.11.12.218',
#  'file:C:/Share/SpectralEntropy/guassian_withLine_triangularNoise_2.png': '192.168.1.2.11.11.12.219',
#  'file:C:/Share/SpectralEntropy/guassian_withLine_uniformNoise_2.png': '192.168.1.2.11.11.12.220',
#  'file:C:/Share/SpectralEntropy/loglogentropyvssignalstrength.png': '192.168.1.2.11.11.12.221'}

# %%
nodes=new_db.document.getElementsByTagName("File")

# %%
node=nodes[0]

# %%
nodes[1].attributes.items()
# Out:
# [('Date', '2018-09-01T04:49:19.187000'),
#  ('URL', 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png'),
#  ('Host', '672PIF-AS1.campus.nist.gov'),
#  ('Type', 'Ordinary'),
#  ('Id', '192.168.1.2.11.11.12.21')]

# %%
data_dictionary_list=[{attribute[0]:attribute[1] for attribute in item.attributes.items()} for item in nodes] 
data=[[attribute[1] for attribute in item.attributes.items()] for item in nodes]

# %%
data
# Out:
# [['2018-09-01T04:44:27.906000',
#   'file:C:/Share/HarmonicWaveletTransform_1.pdf',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.21'],
#  ['2018-09-01T04:49:19.187000',
#   'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.21'],
#  ['2018-09-01T04:49:19.230000',
#   'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.22'],
#  ['2018-09-01T04:49:19.297000',
#   'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.23'],
#  ['2018-09-01T04:49:19.481000',
#   'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.24'],
#  ['2018-09-01T04:49:19.502000',
#   'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.25'],
#  ['2018-09-01T04:49:19.527000',
#   'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.26'],
#  ['2018-09-01T04:49:19.552000',
#   'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.27'],
#  ['2018-09-01T04:49:19.583000',
#   'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.28'],
#  ['2018-09-01T04:49:19.617000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.29'],
#  ['2018-09-01T04:49:19.640000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.210'],
#  ['2018-09-01T04:49:19.667000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.211'],
#  ['2018-09-01T04:49:19.696000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.212'],
#  ['2018-09-01T04:49:19.727000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.213'],
#  ['2018-09-01T04:49:19.758000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.214'],
#  ['2018-09-01T04:49:19.789000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.215'],
#  ['2018-09-01T04:49:19.823000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.216'],
#  ['2018-09-01T04:49:19.855000',
#   'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.217'],
#  ['2018-09-01T04:49:19.886000',
#   'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.218'],
#  ['2018-09-01T04:49:19.921000',
#   'file:C:/Share/SpectralEntropy/guassian_withLine_triangularNoise_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.219'],
#  ['2018-09-01T04:49:19.954000',
#   'file:C:/Share/SpectralEntropy/guassian_withLine_uniformNoise_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.220'],
#  ['2018-09-01T04:49:19.986000',
#   'file:C:/Share/SpectralEntropy/loglogentropyvssignalstrength.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.221'],
#  ['2018-09-01T04:49:20.015000',
#   'file:C:/Share/SpectralEntropy/LogLogentropyvssignalstrength_wide.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.222'],
#  ['2018-09-01T04:49:20.050000',
#   'file:C:/Share/SpectralEntropy/NoNoise.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.223'],
#  ['2018-09-01T04:49:20.083000',
#   'file:C:/Share/SpectralEntropy/Se45PowerFit.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.224'],
#  ['2018-09-01T04:49:20.112000',
#   'file:C:/Share/SpectralEntropy/SE64PowerFitOfSE91Lorentzian.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.225'],
#  ['2018-09-01T04:49:20.145000',
#   'file:C:/Share/SpectralEntropy/SE85_LorentzianFit.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.226'],
#  ['2018-09-01T04:49:20.175000',
#   'file:C:/Share/SpectralEntropy/Se91LorentzianFit.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.227'],
#  ['2018-09-01T04:49:20.209000',
#   'file:C:/Share/SpectralEntropy/Se94_Gaussian_ofSE91Lorentzian.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.228'],
#  ['2018-09-01T04:49:20.240000',
#   'file:C:/Share/SpectralEntropy/SE95_GaussainFit.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.229'],
#  ['2018-09-01T04:49:20.274000',
#   'file:C:/Share/SpectralEntropy/SE_Normal_Vs_SampleSize.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.230'],
#  ['2018-09-01T04:49:20.302000',
#   'file:C:/Share/SpectralEntropy/SignalPlusNoiseSE93.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.231'],
#  ['2018-09-01T04:49:20.337000',
#   'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.232'],
#  ['2018-09-01T04:49:20.476000',
#   'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.233'],
#  ['2018-09-01T04:49:20.532000',
#   'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_3.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.234'],
#  ['2018-09-01T04:49:20.602000',
#   'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_4.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.235'],
#  ['2018-09-01T04:49:20.633000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.236'],
#  ['2018-09-01T04:49:20.665000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.237'],
#  ['2018-09-01T04:49:20.699000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_3.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.238'],
#  ['2018-09-01T04:49:20.736000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_4.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.239'],
#  ['2018-09-01T04:49:20.769000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_5.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.240'],
#  ['2018-09-01T04:49:20.801000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_6.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.241'],
#  ['2018-09-01T04:49:20.836000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_7.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.242'],
#  ['2018-09-01T04:49:20.871000',
#   'file:C:/Share/SpectralEntropy/VisibleEffectOnEntropy.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.243']]

# %%
class FileRegister(XMLBase):
    """ The base class for arbitrary database, which processes the
    File Register XML File."""

    def __init__(self,file_path=None,**options):
        """ Initializes the File Register Class."""

        # This is a general pattern for adding a lot of options
        # The next more advanced thing to do is retrieve defaults from a settings file
        defaults={"root":"File_Registry",
                  "style_sheet":DEFAULT_REGISTER_STYLE,
                  "specific_descriptor":'Resource',
                  "general_descriptor":'Registry',
                  "directory":None,
                  "extension":'xml'
                  }
        self.options={}
        for key,value in defaults.iteritems():
            self.options[key]=value
        for key,value in options.iteritems():
            self.options[key]=value
        XMLBase.__init__(self,file_path,**self.options)

        self.Id_dictionary=dict([(str(node.getAttribute('URL')),
            str(node.getAttribute('Id'))) for node in
            self.document.getElementsByTagName('File')])


    def create_Id(self,URL):
        """ Returns or returns the existing Id element of a URL"""
        parsed_URL=urlparse.urlparse(condition_URL(URL))
        try: # Look in self.Id_dictionary, if it is not there catch
             # the exception KeyError and generate an Id.
            return self.Id_dictionary[URL.replace('///','')]
        except KeyError:
            # The Id is not in the existing list so start buliding Id.
            # Determine the IP Address of the host in the URL
            if parsed_URL[1] in ['',u'']: #if it is empty assume local host
                IP_address=socket.gethostbyaddr(socket.gethostname())[2][0]
            else:
                IP_address= socket.gethostbyaddr(parsed_URL[1])[2][0]
            Id_cache={}
            # We begin with all the entries with the same IP address
            for (key,value) in self.Id_dictionary.iteritems():
                if value.startswith(IP_address):
                        Id_cache[key]=value
            # If the Id_cache is empty then we just assign the number
            temp_Id=IP_address
            path_list=parsed_URL[2].split('/')
            file_extension=path_list[-1].split('.')[-1]
            if len(Id_cache) is 0:
                for index,part in enumerate(path_list):
                    if index<len(path_list)-1:
                        temp_Id=temp_Id+'.'+'11'
                    elif index==len(path_list)-1:
                        if (file_extension in DRIVER_FILE_EXTENSIONS):
                            temp_Id=temp_Id+'.'+'31'
                        elif os.path.isdir(parsed_URL[2]):
                            temp_Id=temp_Id+'.'+'11'
                        else:
                            temp_Id=temp_Id+'.'+'21'
                return temp_Id
            # if it is not empty we have to a little work
            # remove the information about IP address
            place=0
            #print path_list
            while place<=len(path_list):
            # If the Id_cache is empty assign the rest of the Id.
               if len(Id_cache) is 0:
                    for index,part in enumerate(path_list[place:]):
                        if index<len(path_list[place:])-1:
                            temp_Id=temp_Id+'.'+'11'
                        elif index==len(path_list[place:])-1:
                            if (file_extension in DRIVER_FILE_EXTENSIONS):
                                temp_Id=temp_Id+'.'+'31'
                            elif os.path.isdir(parsed_URL[2]):
                                temp_Id=temp_Id+'.'+'11'
                            else:
                                temp_Id=temp_Id+'.'+'21'
                    return temp_Id

                # If the Id_cache is not empty
               else:
                    path_cache=dict([(URL,URL_to_path(URL,form='list'))
                        for URL in Id_cache.keys()])
                    #print Id_cache
                    part_cache=dict([(URL,[path_cache[URL][place],
                        Id_cache[URL].split('.')[place+4]])
                        for URL in Id_cache.keys()])
                    parts_list=[part_cache[URL][0]for URL in Id_cache.keys()]
                    node_number=max([int(Id_cache[URL].split('.')[place+4][1:])
                        for URL in Id_cache.keys()])
                # If it is the last place
                    if place==len(path_list)-1:
                        new_node_number=node_number+1
                        if (file_extension in DRIVER_FILE_EXTENSIONS):
                            new_node_type='3'
                        elif os.path.isdir(parsed_URL[2]):
                            new_node_type='1'
                        else:
                            new_node_type='2'
                        temp_Id=temp_Id+'.'+new_node_type+str(new_node_number)
                        return temp_Id
                # If it is not the last place assume it is a directory
                    else:
                        new_node_type='1'
                        # Check to see if it is already in the FR
                        if path_list[place] in parts_list:
                            for URL in Id_cache.keys():
                                if part_cache[URL][0]==path_list[place]:
                                    new_node=part_cache[URL][1]

                        # If not add one to node
                        else:
                            new_node_number=node_number+1
                            new_node=new_node_type+str(new_node_number)
                        temp_Id=temp_Id+'.'+new_node
                        # Update the Id_cache for the next round, and the place
                        for URL in Id_cache.keys():
                            try:
                                if not part_cache[URL][0]==path_list[place]:
                                    del(Id_cache[URL])
                                Id_cache[URL].split('.')[place+5]
                            except KeyError:
                                pass
                            except IndexError:
                                #print Id_cache,URL
                                del(Id_cache[URL])
                        place=place+1

    def add_entry(self,URL):
        """ Adds an entry to the current File Register """
        URL=condition_URL(URL)
        if URL in self.Id_dictionary.keys():
            print 'Already there'
            return
        # the xml entry is <File Date="" Host="" Type="" Id="" URL=""/>
        File_Registry=self.document.documentElement
        new_entry=self.document.createElement('File')
        # Make all the new attributes
        attributes=['Id','Host','Date','URL','Type']
        new_attributes=dict([(attribute,
        self.document.createAttribute(attribute)) for attribute in \
        attributes])
        # Add the new attributes to the new entry
        for attribute in attributes:
            new_entry.setAttributeNode(new_attributes[attribute])
        # Now assign the values
        attribute_values={}
        attribute_values['URL']=URL
        attribute_values['Id']=self.create_Id(URL)
        attribute_values['Date']=datetime.datetime.utcnow().isoformat()
        type_code=attribute_values['Id'].split('.')[-1][0]
        if type_code in ['1',u'1']:
            attribute_values['Type']="Directory"
        elif type_code in ['2',u'2']:
            attribute_values['Type']="Ordinary"
        elif type_code in ['3',u'3']:
            attribute_values['Type']="Driver"
        else:
            attribute_values['Type']="Other"
        parsed_URL=urlparse.urlparse(condition_URL(URL))
        if parsed_URL[1] in ['',u'']: #if it is empty assume local host
            attribute_values['Host']= socket.gethostbyaddr(socket.gethostname())[0]
        else:
            attribute_values['Host']= parsed_URL[1]

        # Now set them all in the actual attribute
        for (key,value) in attribute_values.iteritems():
            new_entry.setAttribute(key,value)
        File_Registry.appendChild(new_entry)
        # Finally update the self.Id_dictionary
        # Added boolean switch to speed up adding a lot of entries

        self.Id_dictionary=dict([(str(node.getAttribute('URL')),
            str(node.getAttribute('Id'))) for node in
            self.document.getElementsByTagName('File')])
    # TODO : Add an input filter that guesses at what you inputed

    def add_tree(self,root,**options):
        """ Adds a directory and all sub folders and sub directories, **options
        provides a way to {'ignore','.pyc|etc'} or {'only','.png|.bmp'}"""

        # Deal with the optional parameters, these tend to make life easier
        default_options={'ignore':None,'only':None,'print_ignored_files':True,
        'directories_only':False,'files_only':False}
        tree_options=default_options
        for option,value in options.iteritems():
            tree_options[option]=value
        #print tree_options
        #condition the URL
        root_URL=condition_URL(root)
        path=URL_to_path(root_URL)
        # now we add the files and directories that jive with the options
        try:

            for (home,directories,files) in os.walk(path):
                #print (home,directories,files)
                for directory in directories:# had to change this, used to be first element in list
                    try:
                        if tree_options['files_only']:
                            if tree_options['print_ignored_files']:
                                print "ignoring %s because it is not a file"%file
                            raise
                        if tree_options['ignore'] is not None and re.search(tree_options['ignore'],directory):
                            if tree_options['print_ignored_files']:
                                print "ignoring %s because it does not match the only option"%directory
                            raise
                        elif tree_options['only'] is not None and not re.search(tree_options['only'],directory):
                            if tree_options['print_ignored_files']:
                                print "ignoring %s because it does not match the only option"%directory
                            raise
                        else:
                            self.add_entry(condition_URL(os.path.join(home,directory)))
                            self.save()
                    except:pass
                for file in files: # had to change this 12/2012, used to be Second element in list
                    try:
                        if tree_options['directories_only']:
                            if tree_options['print_ignored_files']:
                                print "ignoring %s because it is not a directory"%file
                            raise
                        if tree_options['ignore'] is not None and re.search(tree_options['ignore'],file):
                            if tree_options['print_ignored_files']:
                                print "ignoring %s because it matches the ignore option"%file
                            raise
                        elif tree_options['only'] is not None and not re.search(tree_options['only'],file):
                            if tree_options['print_ignored_files']:
                                print "ignoring %s because it does not match the only option"%file
                            raise
                        else:
                            #print (home,file)
                            self.add_entry(condition_URL(os.path.join(home,file)))
                            self.save()
                    except:raise
        except:
            raise
        #After all the files are added update the Id_dictionary
        self.Id_dictionary=dict([(str(node.getAttribute('URL')),
            str(node.getAttribute('Id'))) for node in
            self.document.getElementsByTagName('File')])

    def remove_entry(self,URL=None,Id=None):
        """ Removes an entry in the current File Register """
        File_Registry=self.document.documentElement
        if not URL is None:
            URL=condition_URL(URL)
            URL_FileNode_dictionary=dict([(node.getAttribute('URL'),
            node) for node in self.document.getElementsByTagName('File')])
            File_Registry.removeChild(URL_FileNode_dictionary[URL])
        else:
            Id_FileNode_dictionary=dict([(node.getAttribute('Id'),
            node) for node in self.document.getElementsByTagName('File')])
            File_Registry.removeChild(Id_FileNode_dictionary[Id])
        # Finally update the self.Id_dictionary
        self.Id_dictionary=dict([(str(node.getAttribute('URL')),
        str(node.getAttribute('Id'))) for node in \
        self.document.getElementsByTagName('File')])
        
    def get_data(self):
        """Gets a list of lists that represent the data in the file register"""
        node_list=self.document.getElementsByTagName("File")
        data=[[attribute[1] for attribute in item.attributes.items()] for item in node_list]
        return data
    
    def get_data_dictionary_list(self):
        """Returns a list of dictionaries that have the data in the file register attributes"""
        node_list=self.document.getElementsByTagName("File")
        data_dictionary_list=[{attribute[0]:attribute[1] for attribute in item.attributes.items()} for item in node_list] 
        return data_dictionary_list

# %%
new_db=FileRegister()
new_db.add_entry(r"C:\Share\HarmonicWaveletTransform_1.pdf")
new_db.add_tree(r"C:\Share\SpectralEntropy")

# %%
new_db.get_data()
# Out:
# [['2018-09-02T04:10:05.028000',
#   'file:C:/Share/HarmonicWaveletTransform_1.pdf',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.21'],
#  ['2018-09-02T04:10:05.065000',
#   'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.21'],
#  ['2018-09-02T04:10:05.107000',
#   'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.22'],
#  ['2018-09-02T04:10:05.309000',
#   'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.23'],
#  ['2018-09-02T04:10:05.326000',
#   'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.24'],
#  ['2018-09-02T04:10:05.345000',
#   'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.25'],
#  ['2018-09-02T04:10:05.365000',
#   'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.26'],
#  ['2018-09-02T04:10:05.388000',
#   'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.27'],
#  ['2018-09-02T04:10:05.411000',
#   'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.28'],
#  ['2018-09-02T04:10:05.432000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.29'],
#  ['2018-09-02T04:10:05.454000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.210'],
#  ['2018-09-02T04:10:05.476000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.211'],
#  ['2018-09-02T04:10:05.498000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.212'],
#  ['2018-09-02T04:10:05.522000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.213'],
#  ['2018-09-02T04:10:05.546000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.214'],
#  ['2018-09-02T04:10:05.570000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.215'],
#  ['2018-09-02T04:10:05.594000',
#   'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.216'],
#  ['2018-09-02T04:10:05.618000',
#   'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.217'],
#  ['2018-09-02T04:10:05.642000',
#   'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.218'],
#  ['2018-09-02T04:10:05.665000',
#   'file:C:/Share/SpectralEntropy/guassian_withLine_triangularNoise_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.219'],
#  ['2018-09-02T04:10:05.691000',
#   'file:C:/Share/SpectralEntropy/guassian_withLine_uniformNoise_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.220'],
#  ['2018-09-02T04:10:05.718000',
#   'file:C:/Share/SpectralEntropy/loglogentropyvssignalstrength.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.221'],
#  ['2018-09-02T04:10:05.745000',
#   'file:C:/Share/SpectralEntropy/LogLogentropyvssignalstrength_wide.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.222'],
#  ['2018-09-02T04:10:05.772000',
#   'file:C:/Share/SpectralEntropy/NoNoise.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.223'],
#  ['2018-09-02T04:10:05.800000',
#   'file:C:/Share/SpectralEntropy/Se45PowerFit.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.224'],
#  ['2018-09-02T04:10:05.828000',
#   'file:C:/Share/SpectralEntropy/SE64PowerFitOfSE91Lorentzian.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.225'],
#  ['2018-09-02T04:10:05.856000',
#   'file:C:/Share/SpectralEntropy/SE85_LorentzianFit.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.226'],
#  ['2018-09-02T04:10:05.885000',
#   'file:C:/Share/SpectralEntropy/Se91LorentzianFit.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.227'],
#  ['2018-09-02T04:10:05.914000',
#   'file:C:/Share/SpectralEntropy/Se94_Gaussian_ofSE91Lorentzian.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.228'],
#  ['2018-09-02T04:10:05.943000',
#   'file:C:/Share/SpectralEntropy/SE95_GaussainFit.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.229'],
#  ['2018-09-02T04:10:05.972000',
#   'file:C:/Share/SpectralEntropy/SE_Normal_Vs_SampleSize.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.230'],
#  ['2018-09-02T04:10:06.001000',
#   'file:C:/Share/SpectralEntropy/SignalPlusNoiseSE93.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.231'],
#  ['2018-09-02T04:10:06.031000',
#   'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.232'],
#  ['2018-09-02T04:10:06.061000',
#   'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.233'],
#  ['2018-09-02T04:10:06.091000',
#   'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_3.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.234'],
#  ['2018-09-02T04:10:06.122000',
#   'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_4.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.235'],
#  ['2018-09-02T04:10:06.152000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_1.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.236'],
#  ['2018-09-02T04:10:06.182000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_2.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.237'],
#  ['2018-09-02T04:10:06.213000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_3.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.238'],
#  ['2018-09-02T04:10:06.245000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_4.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.239'],
#  ['2018-09-02T04:10:06.278000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_5.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.240'],
#  ['2018-09-02T04:10:06.309000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_6.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.241'],
#  ['2018-09-02T04:10:06.341000',
#   'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_7.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.242'],
#  ['2018-09-02T04:10:06.372000',
#   'file:C:/Share/SpectralEntropy/VisibleEffectOnEntropy.png',
#   '672PIF-AS1.campus.nist.gov',
#   'Ordinary',
#   '192.168.1.2.11.11.12.243']]

# %%
new_db.get_data_dictionary_list()
# Out:
# [{'Date': '2018-09-02T03:59:02.748000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.21',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/HarmonicWaveletTransform_1.pdf'},
#  {'Date': '2018-09-02T03:59:02.885000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.21',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png'},
#  {'Date': '2018-09-02T03:59:02.930000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.22',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/entropyvssignalstrength.png'},
#  {'Date': '2018-09-02T03:59:02.971000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.23',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/entropyvssignalstrength_wide.png'},
#  {'Date': '2018-09-02T03:59:02.996000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.24',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty.png'},
#  {'Date': '2018-09-02T03:59:03.025000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.25',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/Entropy_w_uncertainty_log_log.png'},
#  {'Date': '2018-09-02T03:59:03.116000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.26',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_1.png'},
#  {'Date': '2018-09-02T03:59:03.174000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.27',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_2.png'},
#  {'Date': '2018-09-02T03:59:03.204000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.28',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/GaussianNoise_Signal_underlying_4.png'},
#  {'Date': '2018-09-02T03:59:03.235000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.29',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/GaussianWNoise_1.png'},
#  {'Date': '2018-09-02T03:59:03.265000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.210',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/GaussianWNoise_2.png'},
#  {'Date': '2018-09-02T03:59:03.293000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.211',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/GaussianWNoise_3.png'},
#  {'Date': '2018-09-02T03:59:03.363000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.212',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_1.png'},
#  {'Date': '2018-09-02T03:59:03.415000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.213',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_2.png'},
#  {'Date': '2018-09-02T03:59:03.459000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.214',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/GaussianWNoise_Lorentzian_fit_3.png'},
#  {'Date': '2018-09-02T03:59:03.488000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.215',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_1.png'},
#  {'Date': '2018-09-02T03:59:03.520000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.216',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/GaussianWNoise_Polynominal_fit_2.png'},
#  {'Date': '2018-09-02T03:59:03.555000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.217',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_1.png'},
#  {'Date': '2018-09-02T03:59:03.596000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.218',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/guassian_withLine_gaussianNoise_2.png'},
#  {'Date': '2018-09-02T03:59:03.626000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.219',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/guassian_withLine_triangularNoise_2.png'},
#  {'Date': '2018-09-02T03:59:03.654000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.220',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/guassian_withLine_uniformNoise_2.png'},
#  {'Date': '2018-09-02T03:59:03.683000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.221',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/loglogentropyvssignalstrength.png'},
#  {'Date': '2018-09-02T03:59:03.716000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.222',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/LogLogentropyvssignalstrength_wide.png'},
#  {'Date': '2018-09-02T03:59:03.753000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.223',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/NoNoise.png'},
#  {'Date': '2018-09-02T03:59:03.789000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.224',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/Se45PowerFit.png'},
#  {'Date': '2018-09-02T03:59:03.826000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.225',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/SE64PowerFitOfSE91Lorentzian.png'},
#  {'Date': '2018-09-02T03:59:03.855000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.226',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/SE85_LorentzianFit.png'},
#  {'Date': '2018-09-02T03:59:03.887000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.227',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/Se91LorentzianFit.png'},
#  {'Date': '2018-09-02T03:59:03.919000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.228',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/Se94_Gaussian_ofSE91Lorentzian.png'},
#  {'Date': '2018-09-02T03:59:03.950000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.229',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/SE95_GaussainFit.png'},
#  {'Date': '2018-09-02T03:59:03.989000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.230',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/SE_Normal_Vs_SampleSize.png'},
#  {'Date': '2018-09-02T03:59:04.033000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.231',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/SignalPlusNoiseSE93.png'},
#  {'Date': '2018-09-02T03:59:04.109000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.232',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_1.png'},
#  {'Date': '2018-09-02T03:59:04.165000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.233',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_2.png'},
#  {'Date': '2018-09-02T03:59:04.192000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.234',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_3.png'},
#  {'Date': '2018-09-02T03:59:04.228000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.235',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/TriangulaNoise_Signal_underlying_4.png'},
#  {'Date': '2018-09-02T03:59:04.261000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.236',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_1.png'},
#  {'Date': '2018-09-02T03:59:04.286000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.237',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_2.png'},
#  {'Date': '2018-09-02T03:59:04.313000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.238',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_3.png'},
#  {'Date': '2018-09-02T03:59:04.342000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.239',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_4.png'},
#  {'Date': '2018-09-02T03:59:04.368000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.240',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_5.png'},
#  {'Date': '2018-09-02T03:59:04.400000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.241',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_6.png'},
#  {'Date': '2018-09-02T03:59:04.434000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.242',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/UniformNoise_Signal_underlying_7.png'},
#  {'Date': '2018-09-02T03:59:04.480000',
#   'Host': '672PIF-AS1.campus.nist.gov',
#   'Id': '192.168.1.2.11.11.12.243',
#   'Type': 'Ordinary',
#   'URL': 'file:C:/Share/SpectralEntropy/VisibleEffectOnEntropy.png'}]

# %%
metadata=Metadata(new_db)

# %%
metadata.print_current_node()
# Out:
# <File Date="2018-09-02T04:10:05.065000" Host="672PIF-AS1.campus.nist.gov" Id="192.168.1.2.11.11.12.21" Type="Ordinary" URL="file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png"/>

# %%
metadata.add_element_to_current_node("Notes","This is an image")

# %%
metadata.print_current_node()
# Out:
# <File Date="2018-09-02T04:10:05.065000" Host="672PIF-AS1.campus.nist.gov" Id="192.168.1.2.11.11.12.21" Type="Ordinary" URL="file:C:/Share/SpectralEntropy/EntropyOfDifferentDistributions.png"><Notes>This is an image</Notes></File>

# %%
metadata.name_dictionary
# Out:
# {'192.168.1.2.11.11.12.21': 'EntropyOfDifferentDistributions.png',
#  '192.168.1.2.11.11.12.210': 'GaussianWNoise_2.png',
#  '192.168.1.2.11.11.12.211': 'GaussianWNoise_3.png',
#  '192.168.1.2.11.11.12.212': 'GaussianWNoise_Lorentzian_fit_1.png',
#  '192.168.1.2.11.11.12.213': 'GaussianWNoise_Lorentzian_fit_2.png',
#  '192.168.1.2.11.11.12.214': 'GaussianWNoise_Lorentzian_fit_3.png',
#  '192.168.1.2.11.11.12.215': 'GaussianWNoise_Polynominal_fit_1.png',
#  '192.168.1.2.11.11.12.216': 'GaussianWNoise_Polynominal_fit_2.png',
#  '192.168.1.2.11.11.12.217': 'guassian_withLine_gaussianNoise_1.png',
#  '192.168.1.2.11.11.12.218': 'guassian_withLine_gaussianNoise_2.png',
#  '192.168.1.2.11.11.12.219': 'guassian_withLine_triangularNoise_2.png',
#  '192.168.1.2.11.11.12.22': 'entropyvssignalstrength.png',
#  '192.168.1.2.11.11.12.220': 'guassian_withLine_uniformNoise_2.png',
#  '192.168.1.2.11.11.12.221': 'loglogentropyvssignalstrength.png',
#  '192.168.1.2.11.11.12.222': 'LogLogentropyvssignalstrength_wide.png',
#  '192.168.1.2.11.11.12.223': 'NoNoise.png',
#  '192.168.1.2.11.11.12.224': 'Se45PowerFit.png',
#  '192.168.1.2.11.11.12.225': 'SE64PowerFitOfSE91Lorentzian.png',
#  '192.168.1.2.11.11.12.226': 'SE85_LorentzianFit.png',
#  '192.168.1.2.11.11.12.227': 'Se91LorentzianFit.png',
#  '192.168.1.2.11.11.12.228': 'Se94_Gaussian_ofSE91Lorentzian.png',
#  '192.168.1.2.11.11.12.229': 'SE95_GaussainFit.png',
#  '192.168.1.2.11.11.12.23': 'entropyvssignalstrength_wide.png',
#  '192.168.1.2.11.11.12.230': 'SE_Normal_Vs_SampleSize.png',
#  '192.168.1.2.11.11.12.231': 'SignalPlusNoiseSE93.png',
#  '192.168.1.2.11.11.12.232': 'TriangulaNoise_Signal_underlying_1.png',
#  '192.168.1.2.11.11.12.233': 'TriangulaNoise_Signal_underlying_2.png',
#  '192.168.1.2.11.11.12.234': 'TriangulaNoise_Signal_underlying_3.png',
#  '192.168.1.2.11.11.12.235': 'TriangulaNoise_Signal_underlying_4.png',
#  '192.168.1.2.11.11.12.236': 'UniformNoise_Signal_underlying_1.png',
#  '192.168.1.2.11.11.12.237': 'UniformNoise_Signal_underlying_2.png',
#  '192.168.1.2.11.11.12.238': 'UniformNoise_Signal_underlying_3.png',
#  '192.168.1.2.11.11.12.239': 'UniformNoise_Signal_underlying_4.png',
#  '192.168.1.2.11.11.12.24': 'Entropy_w_uncertainty.png',
#  '192.168.1.2.11.11.12.240': 'UniformNoise_Signal_underlying_5.png',
#  '192.168.1.2.11.11.12.241': 'UniformNoise_Signal_underlying_6.png',
#  '192.168.1.2.11.11.12.242': 'UniformNoise_Signal_underlying_7.png',
#  '192.168.1.2.11.11.12.243': 'VisibleEffectOnEntropy.png',
#  '192.168.1.2.11.11.12.25': 'Entropy_w_uncertainty_log_log.png',
#  '192.168.1.2.11.11.12.26': 'GaussianNoise_Signal_underlying_1.png',
#  '192.168.1.2.11.11.12.27': 'GaussianNoise_Signal_underlying_2.png',
#  '192.168.1.2.11.11.12.28': 'GaussianNoise_Signal_underlying_4.png',
#  '192.168.1.2.11.11.12.29': 'GaussianWNoise_1.png',
#  '192.168.1.2.11.11.21': 'HarmonicWaveletTransform_1.pdf'}
