# %%
from pyMeasure.Code.DataHandlers.GraphModels import *
# Out:
# Importing Code.Utils.Names
# Importing Code.DataHandlers.NISTModels
# The module smithplot was not found,please put it on the python path
# Importing Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.TouchstoneModels
# The module smithplot was not found,please put it on the python path
# Importing Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.RadiCALModels
# Importing Code.DataHandlers.ZipModels
# Importing Code.DataHandlers.Translations
# Importing Code.DataHandlers.StatistiCALModels
# Importing Code.DataHandlers.MUFModels
# Importing Code.Analysis.SParameter
# Importing Code.Analysis.Uncertainty
# Importing Code.InstrumentControl.Instruments
# Importing Code.InstrumentControl.Experiments
# Importing Code.FrontEnds.AdvancedInterfaceFrame
# C:\ProgramData\Anaconda2\lib\site-packages\matplotlib\__init__.py:1401: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# ...

# %%
table_graph=TableGraph()

# %%
# %matplotlib notebook
table_graph.show()
# Out:
# <img src="data:image/png;base64,..." width="918">
# <img src="data:image/png;base64,..." width="918">

# %%
def visit_all_nodes(graph):
    """Visit all nodes visits each node on a graph"""
    nodes=graph.node_names
    for node in nodes:
        graph.move_to_node(node)

# %%
visit_all_nodes(table_graph)
# Out:
# ['edge_DataFrame_AsciiDataTable_000', 'edge_AsciiDataTable_DataFrame_000']
# moving DataFrame -> AsciiDataTable
# moving AsciiDataTable -> DataFrame
# ['edge_DataFrame_AsciiDataTable_000']
# moving DataFrame -> AsciiDataTable
# ['edge_AsciiDataTable_DataFrame_000', 'edge_DataFrame_HdfFile_000']
# moving AsciiDataTable -> DataFrame
# moving DataFrame -> HdfFile
# ['edge_HdfFile_DataFrame_000', 'edge_DataFrame_AsciiDataTable_000', 'edge_AsciiDataTable_XmlDataTable_000']
# moving HdfFile -> DataFrame
# moving DataFrame -> AsciiDataTable
# moving AsciiDataTable -> XmlDataTable
# equality_list is [True, False, True, False, False]
# equality_list is [True, False, True, False, False]
# ['edge_XmlDataTable_AsciiDataTable_000', 'edge_AsciiDataTable_DataFrame_000', 'edge_DataFrame_ExcelFile_000']
# moving XmlDataTable -> AsciiDataTable
# moving AsciiDataTable -> DataFrame
# moving DataFrame -> ExcelFile
# ['edge_ExcelFile_OdsFile_000']
# moving ExcelFile -> OdsFile
# ...

# %%
from pyMeasure.Code.Utils.PerformanceUtils import timer

# %%
@timer
def visit_all_nodes(graph):
    """Visit all nodes visits each node on a graph"""
    nodes=graph.node_names
    for node in nodes:
        graph.move_to_node(node)

# %%
visit_all_nodes(table_graph)
# Out:
# ['edge_HtmlFile_HtmlString_000', 'edge_HtmlString_DataFrame_000']
# moving HtmlFile -> HtmlString
# moving HtmlString -> DataFrame
# ['edge_DataFrame_AsciiDataTable_000']
# moving DataFrame -> AsciiDataTable
# ['edge_AsciiDataTable_DataFrame_000', 'edge_DataFrame_HdfFile_000']
# moving AsciiDataTable -> DataFrame
# moving DataFrame -> HdfFile
# ['edge_HdfFile_DataFrame_000', 'edge_DataFrame_AsciiDataTable_000', 'edge_AsciiDataTable_XmlDataTable_000']
# moving HdfFile -> DataFrame
# moving DataFrame -> AsciiDataTable
# moving AsciiDataTable -> XmlDataTable
# equality_list is [True, False, True, False, False]
# equality_list is [True, False, True, False, False]
# ['edge_XmlDataTable_AsciiDataTable_000', 'edge_AsciiDataTable_DataFrame_000', 'edge_DataFrame_ExcelFile_000']
# moving XmlDataTable -> AsciiDataTable
# moving AsciiDataTable -> DataFrame
# moving DataFrame -> ExcelFile
# ['edge_ExcelFile_OdsFile_000']
# moving ExcelFile -> OdsFile
# ...

# %%
table_graph.set_state("CsvFile","iouzipcodes2011.csv")

# %%
visit_all_nodes(table_graph)
# Out:
# ['edge_DataFrame_AsciiDataTable_000', 'edge_AsciiDataTable_DataFrame_000']
# moving DataFrame -> AsciiDataTable
# moving AsciiDataTable -> DataFrame
# ['edge_DataFrame_AsciiDataTable_000']
# moving DataFrame -> AsciiDataTable
# ['edge_AsciiDataTable_DataFrame_000', 'edge_DataFrame_HdfFile_000']
# moving AsciiDataTable -> DataFrame
# moving DataFrame -> HdfFile
# ['edge_HdfFile_DataFrame_000', 'edge_DataFrame_AsciiDataTable_000', 'edge_AsciiDataTable_XmlDataTable_000']
# moving HdfFile -> DataFrame
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\pytables.py:270: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->unicode,key->axis0] [items->None]
#
#   f(store)
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\pytables.py:270: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# ...

# %%
image_graph=ImageGraph()

# %%
image_graph.add_external_node(external_node_name="favicon",jump_into_node_begin="Image",
                             jump_into_node_function=Image_to_FaviconFile)

# %%
plt.close()
image_graph.show();
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
image_graph.set_state('jpg','Penguins.jpg')

# %%
# Out:
# ['edge_MatplotlibFigure_png_000', 'edge_png_Image_000']
# moving MatplotlibFigure -> png
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f5cac6d07259> in <module>()
# ----> 1 image_graph.jump_to_external_node("favicon",file_path="FigFavicon.png")
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyMeasure\Code\DataHandlers\GraphModels.pyc in jump_to_external_node(self, external_node_name, **options)
#     376                 begin_node=jump_match.groupdict()["begin_node"]
#     377
# --> 378         self.move_to_node(begin_node)
#     379         return self.__dict__[jump_to_use](self.data,**options)
#     380
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyMeasure\Code\DataHandlers\GraphModels.pyc in move_to_node(self, node)
#     526         """Moves from current_node to the specified node"""
#     527         path=self.get_path(self.current_node,node)
# ...

# %%
def FigFile_to_MatplotlibFigure(filename,fignr=1):
    "Function that uses loadmat to create a matplotlib plot of a matlab fig file"
    from scipy.io import loadmat
    from numpy import size
    from matplotlib.pyplot import plot,figure,hold,xlabel,ylabel,show,clf,xlim,legend
    d = loadmat(filename,squeeze_me=True, struct_as_record=False)
    ax1 = d['hgS_070000'].children
    if size(ax1) > 1:
        legs= ax1[1]
        ax1 = ax1[0]
    else:
        legs=0
    fig=figure(fignr)
    clf()
    hold(True)
    counter = 0
    for line in ax1.children:
        if line.type == 'graph2d.lineseries':
            if hasattr(line.properties,'Marker'):
                mark = "%s" % line.properties.Marker
                mark = mark[0]
            else:
                mark = '.'
            if hasattr(line.properties,'LineStyle'):
                linestyle = "%s" % line.properties.LineStyle
            else:
                linestyle = '-'
            if hasattr(line.properties,'Color'):
                r,g,b =  line.properties.Color
            else:
                r = 0
                g = 0
                b = 1
            if hasattr(line.properties,'MarkerSize'):
                marker_size = line.properties.MarkerSize
            else:
                marker_size = 1
            x = line.properties.XData
            y = line.properties.YData
            plot(x,y,marker=mark,linestyle=linestyle,color=(r,g,b),markersize=marker_size)
        elif line.type == 'text':
            if counter <1:
                #print(dir(line.properties))
                counter += 1
            elif counter < 2:
                #print dir(line.properties.String)
                xlabel("%s" % line.properties.String,fontsize = 16)
                counter += 1
            elif counter < 3:
                #print dir(line.properties.String)
                ylabel("%s" % line.properties.String,fontsize = 16)
                counter += 1
    xlim(ax1.properties.XLim)
    if legs:
        leg_entries = tuple(legs.properties.String)
        py_locs = ['upper center','lower center','right','left','upper right','upper left','lower right','lower left','best']
        MAT_locs=['North','South','East','West','NorthEast', 'NorthWest', 'SouthEast', 'SouthWest','Best']
        Mat2py = dict(zip(MAT_locs,py_locs))
        location = legs.properties.Location
        legend(leg_entries,loc=Mat2py[location])
    hold(False)
    show()
    return fig

# %%
image_graph.set_state("MatplotlibFigure",FigFile_to_MatplotlibFigure("PropagationConstant.fig"))
image_graph.jump_to_external_node("favicon",file_path="FigFavicon.png")
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel\__main__.py:15: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel\__main__.py:61: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
# ['edge_MatplotlibFigure_png_000', 'edge_png_Image_000']
# moving MatplotlibFigure -> png
# moving png -> Image
# 'FigFavicon.png'

# %%
#png=SvgFile_to_PngFile("Diagram_Data_Table_20160122_02.svg","Test.png")
image_graph.set_state("png",SvgFile_to_PngFile("Diagram_Data_Table_20160122_02.svg","Test.png"))
image_graph.jump_to_external_node("favicon",file_path="SvgFavicon.png")
# Out:
# ['edge_png_Image_000']
# moving png -> Image
# 'SvgFavicon.png'

# %%
visit_all_nodes(image_graph)
# Out:
# ['edge_jpg_Image_000']
# moving jpg -> Image
# ['edge_Image_png_000']
# moving Image -> png
# pil_image.mode is RGB
# ['edge_png_Image_000', 'edge_Image_jpg_000']
# moving png -> Image
# moving Image -> jpg
# pil_image.mode is RGB
# ['edge_jpg_Image_000', 'edge_Image_tiff_000']
# moving jpg -> Image
# moving Image -> tiff
# pil_image.mode is RGB
# ['edge_tiff_Image_000', 'edge_Image_gif_000']
# moving tiff -> Image
# moving Image -> gif
# pil_image.mode is RGB
# ['edge_gif_Image_000', 'edge_Image_bmp_000']
# moving gif -> Image
# moving Image -> bmp
# pil_image.mode is RGB
# ['edge_bmp_Image_000', 'edge_Image_png_000', 'edge_png_base64_000']
# moving bmp -> Image
# moving Image -> png
# pil_image.mode is RGB
# moving png -> base64
# ['edge_base64_embeddedHTML_000']
# moving base64 -> embeddedHTML
# ['edge_embeddedHTML_base64_000', 'edge_base64_png_000', 'edge_png_ndarray_000']
# moving embeddedHTML -> base64
# moving base64 -> png
# moving png -> ndarray
# ...

# %%
two_parameter_graph=TwoPortParameterGraph()

# %%
two_parameter_graph.show()

# %%
s2p=S2PV1(os.path.join(TESTS_DIRECTORY,"TwoPortTouchstoneTestFile.s2p"))

# %%
two_parameter_graph.set_state('SFrequencyList',s2p.sparameter_complex)

# %%
visit_all_nodes(two_parameter_graph)
# Out:
# ['edge_SFrequencyList_SFrequencyMatrixList_000', 'edge_SFrequencyMatrixList_SFrequencyList_000']
# moving SFrequencyList -> SFrequencyMatrixList
# moving SFrequencyMatrixList -> SFrequencyList
# ['edge_SFrequencyList_SFrequencyMatrixList_000']
# moving SFrequencyList -> SFrequencyMatrixList
# ['edge_SFrequencyMatrixList_TFrequencyMatrixList_000']
# moving SFrequencyMatrixList -> TFrequencyMatrixList
# ['edge_TFrequencyMatrixList_TFrequencyList_000']
# moving TFrequencyMatrixList -> TFrequencyList
# ['edge_TFrequencyList_TFrequencyMatrixList_000', 'edge_TFrequencyMatrixList_SFrequencyMatrixList_000', 'edge_SFrequencyMatrixList_SFrequencyList_000', 'edge_SFrequencyList_ZFrequencyList_000']
# moving TFrequencyList -> TFrequencyMatrixList
# moving TFrequencyMatrixList -> SFrequencyMatrixList
# moving SFrequencyMatrixList -> SFrequencyList
# moving SFrequencyList -> ZFrequencyList
# ['edge_ZFrequencyList_ZFrequencyMatrixList_000']
# moving ZFrequencyList -> ZFrequencyMatrixList
# ...

# %%
@timer
def visit_and_print_all_nodes(graph):
    """Visits all the nodes in graph and prints graph.data after each move"""
    nodes=graph.node_names
    for node in nodes:
        graph.move_to_node(node)
        print(graph.data)

# %%
visit_and_print_all_nodes(two_parameter_graph)
# Out:
# equality_list is [False, False, True, False, True, False, False]
# equality_list is [False, False, True, False, True, False, False]
# ['edge_YFrequencyMatrixList_YFrequencyList_000', 'edge_YFrequencyList_HFrequencyList_000', 'edge_HFrequencyList_ZFrequencyList_000', 'edge_ZFrequencyList_ABCDFrequencyList_000', 'edge_ABCDFrequencyList_SFrequencyList_000']
# moving YFrequencyMatrixList -> YFrequencyList
# moving YFrequencyList -> HFrequencyList
# moving HFrequencyList -> ZFrequencyList
# moving ZFrequencyList -> ABCDFrequencyList
# moving ABCDFrequencyList -> SFrequencyList
# ...

# %%
two_parameter_graph.move_to_node('SFrequencyList')
# Out:
# equality_list is [False, False, True, False, True, False, False]
# equality_list is [False, False, True, False, True, False, False]
# ['edge_YFrequencyMatrixList_YFrequencyList_000', 'edge_YFrequencyList_HFrequencyList_000', 'edge_HFrequencyList_ZFrequencyList_000', 'edge_ZFrequencyList_ABCDFrequencyList_000', 'edge_ABCDFrequencyList_SFrequencyList_000']
# moving YFrequencyMatrixList -> YFrequencyList
# moving YFrequencyList -> HFrequencyList
# moving HFrequencyList -> ZFrequencyList
# moving ZFrequencyList -> ABCDFrequencyList
# moving ABCDFrequencyList -> SFrequencyList

# %%
print(two_parameter_graph.data)
# Out:
# [[1.0, (0.39260000000000039-0.12109999999999987j), (-0.00030000000000000117-0.0021000000000000012j), (-0.00030000000000000117-0.0021000000000000012j), (0.39259999999999984-0.12109999999999989j)], [2.0, (0.3516999999999999-0.30540000000000006j), (-0.0095999999999999905-0.029799999999999993j), (-0.0095999999999999905-0.029799999999999993j), (0.35169999999999996-0.30539999999999989j)], [10.0, (0.34189999999999998+0.33359999999999962j), (-0.013400000000000039+0.037899999999999948j), (-0.013400000000000039+0.037899999999999948j), (0.34189999999999976+0.33359999999999967j)]]

# %%
print s2p.sparameter_complex
# Out:
# [[1.0, (0.3926-0.1211j), (-0.0003-0.0021j), (-0.0003-0.0021j), (0.3926-0.1211j)], [2.0, (0.3517-0.3054j), (-0.0096-0.0298j), (-0.0096-0.0298j), (0.3517-0.3054j)], [10.0, (0.3419+0.3336j), (-0.0134+0.0379j), (-0.0134+0.0379j), (0.3419+0.3336j)]]

# %%
print(np.array(two_parameter_graph.data)-np.array(s2p.sparameter_complex))
# Out:
# [[  0.00000000e+00 +0.00000000e+00j   3.88578059e-16 +1.24900090e-16j
#    -1.19262239e-18 -1.30104261e-18j  -1.19262239e-18 -1.30104261e-18j
#    -1.66533454e-16 +1.11022302e-16j]
#  [  0.00000000e+00 +0.00000000e+00j  -1.11022302e-16 -5.55111512e-17j
#     8.67361738e-18 +6.93889390e-18j   8.67361738e-18 +6.93889390e-18j
#    -5.55111512e-17 +1.11022302e-16j]
#  [  0.00000000e+00 +0.00000000e+00j   0.00000000e+00 -3.88578059e-16j
#    -3.81639165e-17 -5.55111512e-17j  -3.81639165e-17 -5.55111512e-17j
#    -2.22044605e-16 -3.33066907e-16j]]

# %%
image_graph.add_node(node_name="EmbeddedHtmlFile",edge_into_node_begin="embeddedHTML",
                     edge_into_node_function=lambda x:String_to_File(x,"test.html"),
                     edge_out_node_end="embeddedHTML",
                     edge_out_node_function=File_to_String,
                     node_description="Html File")

# %%
visit_all_nodes(image_graph)
# Out:
# ['edge_MatplotlibFigure_png_000', 'edge_png_Image_000']
# moving MatplotlibFigure -> png
# moving png -> Image
# ['edge_Image_png_000']
# moving Image -> png
# pil_image.mode is RGBA
# ['edge_png_Image_000', 'edge_Image_jpg_000']
# moving png -> Image
# moving Image -> jpg
# pil_image.mode is RGBA
# ['edge_jpg_Image_000', 'edge_Image_tiff_000']
# moving jpg -> Image
# moving Image -> tiff
# pil_image.mode is RGB
# ['edge_tiff_Image_000', 'edge_Image_gif_000']
# moving tiff -> Image
# moving Image -> gif
# pil_image.mode is RGB
# ['edge_gif_Image_000', 'edge_Image_bmp_000']
# moving gif -> Image
# moving Image -> bmp
# pil_image.mode is RGB
# ['edge_bmp_Image_000', 'edge_Image_png_000', 'edge_png_base64_000']
# moving bmp -> Image
# moving Image -> png
# pil_image.mode is RGB
# moving png -> base64
# ['edge_base64_embeddedHTML_000']
# moving base64 -> embeddedHTML
# equality_list is [True, False, True, False, False]
# equality_list is [True, False, True, False, False]
# ...

# %%
image_graph.show()

# %%
plt.close()

# %%
image_graph.show()

# %%
image_graph.set_state("jpg","Jellyfish.jpg")

# %%
plt.close()

# %%
visit_all_nodes(image_graph)
# Out:
# ['edge_jpg_Image_000']
# moving jpg -> Image
# ['edge_Image_png_000']
# moving Image -> png
# pil_image.mode is RGB
# ['edge_png_Image_000', 'edge_Image_jpg_000']
# moving png -> Image
# moving Image -> jpg
# pil_image.mode is RGB
# ['edge_jpg_Image_000', 'edge_Image_tiff_000']
# moving jpg -> Image
# moving Image -> tiff
# pil_image.mode is RGB
# ['edge_tiff_Image_000', 'edge_Image_gif_000']
# moving tiff -> Image
# moving Image -> gif
# pil_image.mode is RGB
# ['edge_gif_Image_000', 'edge_Image_bmp_000']
# moving gif -> Image
# moving Image -> bmp
# pil_image.mode is RGB
# ['edge_bmp_Image_000', 'edge_Image_png_000', 'edge_png_base64_000']
# moving bmp -> Image
# moving Image -> png
# pil_image.mode is RGB
# moving png -> base64
# ['edge_base64_embeddedHTML_000']
# moving base64 -> embeddedHTML
# equality_list is [True, False, True, False, False]
# equality_list is [True, False, True, False, False]
# ['edge_embeddedHTML_base64_000', 'edge_base64_png_000', 'edge_png_ndarray_000']
# ...

# %%
# %matplotlib notebook
meta=MetadataGraph()
plt.close()
meta.show()
# Out:
# <img src="data:image/png;base64,..." width="827">
# <img src="data:image/png;base64,..." width="827">

# %%
two_port=TwoPortParameterGraph()
plt.close()
two_port.show(node_names=False);
# Out:
# <img src="data:image/png;base64,..." width="723">
