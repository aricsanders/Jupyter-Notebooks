# %%
from pyMeasure import *
new_data_table=DataTable(r'C:\Users\sandersa\PyCharm Projects\pyMeasure\Data\Measurements\Data_Table_021611_103.xml')

# %%
new_data_table.get_attribute_names()
# Out:
# [u'Current', u'Index', u'Voltage']

# %%
print new_data_table.to_list("Voltage"),new_data_table.to_list("Current")
data_sheet=new_data_table
# Out:
# [u'+000.0000', u'-000.1052', u'-000.2106', u'-000.3158', u'-000.4210', u'-000.5264', u'-000.6316', u'-000.7368', u'-000.8422', u'-000.9474', u'-001.0526', u'-001.1578', u'-001.2632', u'-001.3684', u'-001.4736', u'-001.5790', u'-001.6842', u'-001.7894', u'-001.8948', u'-002.0000', u'-002.0000', u'-001.8948', u'-001.7894', u'-001.6842', u'-001.5790', u'-001.4736', u'-001.3684', u'-001.2632', u'-001.1578', u'-001.0526', u'-000.9474', u'-000.8422', u'-000.7368', u'-000.6316', u'-000.5264', u'-000.4210', u'-000.3158', u'-000.2106', u'-000.1052', u'+000.0000', u'+000.0000', u'+000.1052', u'+000.2106', u'+000.3158', u'+000.4210', u'+000.5264', u'+000.6316', u'+000.7368', u'+000.8422', u'+000.9474', u'+001.0526', u'+001.1578', u'+001.2632', u'+001.3684', u'+001.4736', u'+001.5790', u'+001.6842', u'+001.7894', u'+001.8948', u'+002.0000', u'+002.0000', u'+001.8948', u'+001.7894', u'+001.6842', u'+001.5790', u'+001.4736', u'+001.3684', u'+001.2632', u'+001.1578', u'+001.0526', u'+000.9474', u'+
# ...

# %%
x_data=np.array(map(lambda x:float(x),data_sheet.to_list("Voltage")))
y_data=np.array(map(lambda x:float(x),data_sheet.to_list("Current")))

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import rcParams

# %%
rcParams
# Out:
# RcParams({u'agg.path.chunksize': 0,
#           u'animation.avconv_args': [],
#           u'animation.avconv_path': u'avconv',
#           u'animation.bitrate': -1,
#           u'animation.codec': u'mpeg4',
#           u'animation.convert_args': [],
#           u'animation.convert_path': u'convert',
#           u'animation.ffmpeg_args': [],
#           u'animation.ffmpeg_path': u'ffmpeg',
#           u'animation.frame_format': u'png',
#           u'animation.html': u'none',
#           u'animation.mencoder_args': [],
#           u'animation.mencoder_path': u'mencoder',
#           u'animation.writer': u'ffmpeg',
#           u'axes.axisbelow': False,
#           u'axes.edgecolor': u'k',
#           u'axes.facecolor': u'w',
#           u'axes.formatter.limits': [-7, 7],
#           u'axes.formatter.use_locale': False,
#           u'axes.formatter.use_mathtext': False,
#           u'axes.formatter.useoffset': True,
#           u'axes.grid': False,
# ...
