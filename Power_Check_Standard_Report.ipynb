# %%
from pyMez.Code.Analysis.Reports import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 3.124 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.574 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# It took 8.66 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# It took 0.01 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.267 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.051 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# It took 1.457 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.014 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.008 s to import Code.Utils.Names
# ...

# %%
report_C90P01=CheckStandardReport(None,Device_Id="C90P01")

# %%
report_C90P01.show()

# %%
report_C90P01.options

# %%
report_C90P02=CheckStandardReport(None,Device_Id="C90P02")
report_C90P03=CheckStandardReport(None,Device_Id="C90P03")
directory=r"C:\Share\Example Check Standard Reports"
for report in [report_C90P01,report_C90P02,report_C90P03]:
    report.save(os.path.join(directory,report.options["Device_Id"]+".html"))

# %%
report_C90P02=CheckStandardReport(None,Device_Id="C90P02",conversion_options=None)
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2821: DtypeWarning: Columns (10,11,12,16,18,19,20,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2821: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# C:\ProgramData\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2821: DtypeWarning: Columns (8,9,14,16,17,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# measurement_type is P
# Body tag was not present adding it
# Head tag was not present adding it
# index is 0
# ['edge_AsciiDataTable_XmlDataTable_000', 'edge_XmlDataTable_XmlFile_000']
# moving AsciiDataTable -> XmlDataTable
# moving XmlDataTable -> XmlFile
# ...

# %%
report_C90P02.show()
# Out:
# file://c:/users/sandersa/appdata/local/temp/1/tmpyqvthj.html

# %%
report_C90P02.save(r"C:\Share\Example Check Standard Reports\C90P02_Report_All_Downloads.html")
# Out:
# 'C:\\Share\\Example Check Standard Reports\\C90P02_Report_All_Downloads.html'

# %%
test=CheckStandardReport(r"C:\Share\Ck_Std_raw_ascii\CTN201.L32_020200",conversion_options=None)
# Out:
# Body tag was not present adding it
# Head tag was not present adding it
# index is 0
# ['edge_AsciiDataTable_XmlDataTable_000', 'edge_XmlDataTable_XmlFile_000']
# moving AsciiDataTable -> XmlDataTable
# moving XmlDataTable -> XmlFile
# ['edge_XmlFile_XmlDataTable_000', 'edge_XmlDataTable_AsciiDataTable_000', 'edge_AsciiDataTable_DataFrame_000', 'edge_DataFrame_CsvFile_000']
# moving XmlFile -> XmlDataTable
# moving XmlDataTable -> AsciiDataTable
# moving AsciiDataTable -> DataFrame
# moving DataFrame -> CsvFile
# ['edge_CsvFile_DataFrame_000', 'edge_DataFrame_ExcelFile_000']
# moving CsvFile -> DataFrame
# moving DataFrame -> ExcelFile
# ['edge_ExcelFile_OdsFile_000']
# moving ExcelFile -> OdsFile
# ['edge_OdsFile_ExcelFile_000', 'edge_ExcelFile_DataFrame_000', 'edge_DataFrame_AsciiDataTable_000', 'edge_AsciiDataTable_MatFile_000']
# moving OdsFile -> ExcelFile
# moving ExcelFile -> DataFrame
# moving DataFrame -> AsciiDataTable
# moving AsciiDataTable -> MatFile
# ...

# %%
test.show()
# Out:
# file://c:/users/sandersa/appdata/local/temp/1/tmpcohvec.html

# %%
test.save(r"C:\Share\Example Check Standard Reports\CTN201_L32_020200_Report1.html")
# Out:
# 'C:\\Share\\Example Check Standard Reports\\CTN201_L32_020200_Report1.html'
