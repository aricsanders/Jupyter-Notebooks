# %%
from pyMez import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 1.65 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.312 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# It took 6.452 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# It took 0.015 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.359 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.114 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# It took 1.526 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.022 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.021 s to import Code.Utils.Names
# It took 10.472 s to import all of the active modules

# %%
import visa

# %%
rm=visa.ResourceManager()

# %%
rm.list_resources()

# %%
scope=rm.open_resource("GPIB0::7::INSTR")

# %%
scope.query("*IDN?")

# %%
class HighSpeedOscope(VisaInstrument):
    """Control Class for high speed oscilloscopes. Based on code from Diogo """
    def initialize(self,**options):
        """Initializes the oscilloscope  for data collection"""
        defaults = {"reset": True}
        initialize_options = {}
        for key, value in defaults.iteritems():
            initialize_options[key] = value
        for key, value in options.iteritems():
            initialize_options[key] = value
        pass

    def measure_waves(self,**options):
        """Returns data for a measurement in an AsciiDataTable"""
        defaults = {"number_frames": 1,"number_points":self.get_number_points(),
                    "timebase_scale":self.get_timebase_scale(),"channels":[1,2,3,4],
                    "initial_time_offset":self.get_time_position(),"timeout_measurement":10000,
                    "save_data":False,"data_format":"dat","directory":os.getcwd(),
                    "specific_descriptor":"Scope","general_descriptor":"Measurement","add_header":False,
                    "output_table_options":{"data_delimiter":"  ","treat_header_as_comment":True}
                    }
        self.measure_options = {}
        for key, value in defaults.iteritems():
            self.measure_options[key] = value
        for key, value in options.iteritems():
            self.measure_options[key] = value

        self.set_number_points(self.measure_options["number_points"])
        channel_string_list=["CHAN1","CHAN2","CHAN3","CHAN4"]

        # begin by setting timeout to timeout_measurement
        timeout=self.resource.timeout
        self.resource.timeout=self.measure_options["timeout_measurement"]

        # now calculate timestep
        self.measure_options["timestep"]=self.measure_options["timebase_scale"]/self.measure_options["number_points"]
        time_step=self.measure_options["timestep"]

        # now configure the scope for data transfer
        # define the way the data is transmitted from the instrument to the PC
        # Word -> 16bit signed integer
        self.write(':WAV:FORM WORD')
        # little-endian
        self.write(':WAV:BYT LSBF')
        number_rows=self.measure_options["number_points"]*self.measure_options["number_frames"]
        # this is the way diogo did it
        # number of points
        number_points = self.measure_options["number_points"]
        frames_data = []
        for frame_index in range(self.measure_options["number_frames"]):
            new_frame=[]

            # calculate time position for this frame
            time_position=frame_index*self.measure_options["timebase_scale"]+self.measure_options["initial_time_offset"]

            # define postion to start the acquisition
            self.write(':TIM:POS {0}ns'.format(time_position))

            # acquire channels desired
            channel_string=""
            for channel_index,channel in enumerate(self.measure_options["channels"]):
                if channel_index==len(self.measure_options["channels"])-1:
                    channel_string=channel_string+"{0}".format(channel_string_list[channel-1])
                else:
                    channel_string = channel_string + "{0},".format(channel_string_list[channel - 1])
            channel_command=":DIG {0}".format(channel_string)
            self.write(channel_command)

            # trigger reading and wait
            self.write("*OPC?")

            # get data from the necessary channels
            for channel_read_index,channel_read in enumerate(self.measure_options["channels"]):
                # get data for channel 1
                self.write(':WAV:SOUR CHAN{0}'.format(channel_read))
                # get data
                data_column=self.resource.query_binary_values(':WAV:DATA?', datatype='h')
                new_frame.append(data_column)
                #print("{0} is {1}".format("data_column",data_column))
            frames_data.append(new_frame)
            
        # reshape measurement data
        measurement_data=[range(len(frames_data[0])) for x in range(number_points*len(frames_data))]
#         print(len(measurement_data))
#         print(len(measurement_data[0]))
#         print("{0} is{1}".format("len(frames_data)",len(frames_data)))
#         print("{0} is{1}".format("len(frames_data[0])",len(frames_data[0])))
#         print("{0} is{1}".format("len(frames_data[0][0])",len(frames_data[0][0])))

        for frame_index,frame in enumerate(frames_data):
            for column_index,column in enumerate(frame):
                for row_index,row in enumerate(column):
                    number_rows=len(column)
                    print("{0} is {1}".format("([row_index+frame_index*number_rows],[column_index],[frame_index])",
                                               ([row_index+frame_index*number_rows],[column_index],[frame_index])))
                    measurement_data[row_index+frame_index*number_rows][column_index]=frames_data[frame_index][column_index][row_index]
        # reset timeout
        self.resource.timeout=timeout
        data_out=[]
        time_start=self.measure_options["initial_time_offset"]

        for row_index,data_row in enumerate(measurement_data):
            new_row=[time_start+row_index*time_step]+data_row
            data_out.append(new_row)
        if self.measure_options["add_header"]:
            header=[]
            for key,value in self.measure_options.iteritems():
                header.append("{0} = {1}".format(key,value))
        else:
            header=None
        column_names=["Time"]
        for channel in self.measure_options["channels"]:
            column_names.append(channel_string_list[channel-1])

        table_options={"data":data_out,
                       "header":header,
                       "specific_descriptor":self.measure_options["specific_descriptor"],
                       "general_descriptor":self.measure_options["general_descriptor"],
                       "extension":"dat",
                       "directory":self.measure_options["directory"],"column_names":column_names}
        for key,value in self.measure_options["output_table_options"].iteritems():
            table_options[key]=value
        output_table=AsciiDataTable(None,**table_options)
        if self.measure_options["save_data"]:

            data_save_path=auto_name(specific_descriptor=self.measure_options["specific_descriptor"],
                                     general_descriptor=self.measure_options["general_descriptor"],
                                     directory=self.measure_options["directory"],
                                     extension='dat'
                                     ,padding=3)
            output_table.path=data_save_path
            output_table.save()
        return output_table




    def get_error_state(self):
        """Returns the error state of the oscope"""
        state=self.query(':SYSTEM:ERROR? STRING')
        self.error_state=state
        return state

    def set_number_points(self,number_points=16384):
        """Sets the number of points for the acquisition"""
        self.write(':ACQ:POINTS {0}'.format(number_points))

    def get_number_points(self):
        """Returns the number of points in the waveform"""
        number_points= int(self.query(':ACQ:POINTS?'))
        return number_points

    def set_time_position(self,time=50):
        """Sets the time in ns to start the acquisition"""
        self.write(':TIM:POS {0}ns'.format(time))

    def get_time_position(self):
        """Returns the time position in ns"""
        position=float(self.query(":TIM:POS?"))
        return position*10**9

    def set_timebase_scale(self,time_scale=40.96):
        """Sets the timebase scale in ns"""
        self.write(':TIM:SCAL {0}ns'.format(time_scale))

    def get_timebase_scale(self):
        """Returns the timebase scale in ns"""
        time_scale=float(self.query(':TIM:SCAL?'))
        return time_scale*10**9

    def set_trigger_source(self,source="FPAN"):
        """Sets the tigger source, 'FPAN' Frontpanel or 'FRUN' freerun"""
        self.write(':TRIG:SOUR {0}'.format(source))

    def get_trigger_source(self):
        """Returns the trigger source FPAN for FrontPanel or FRUN for free run"""
        source=self.query(':TRIG:SOUR?')

    def set_trigger_level(self,level=10):
        """Sets the trigger level in mv"""
        self.write(':TRIG:LEV {0}m'.format(level))

    def get_trigger_level(self):
        """Returns the trigger level"""
        level=self.query(':TRIG:LEV?')

    def set_channel_scale(self,scale=10,channel=1):
        """Sets the scale in mv of channel. Default is 10mv/division on channel 1"""
        self.write(':CHAN{0}:SCAL {1}m'.format(channel,scale))

    def get_channel_scale(self,channel=1):
        "Returns the scale for a specified channel, the default is channel 1"
        scale=self.query(':CHAN{0}:SCAL?'.format(channel))
        return scale

    def set_channel_bandwidth(self,bandwidth="LOW",channel=1):
        """Sets the specified channel's bandwith to LOW, MED or HIGH, default is to set channel 1 to LOW"""
        self.write(':CHAN{0}:BAND {1}'.format(channel,bandwidth))

    def get_channel_bandwidth(self,channel=1):
        """Returns the selected channels bandwidth"""
        bandwidth=self.query(':CHAN{0}:BAND?'.format(channel))
        return bandwidth

    def set_trigger_slope(self,slope="POS"):
        """Sets the trigger slope on the oscope choose from POS or NEG"""
        self.write(':TRIG:SLOP {0}'.format(slope))

    def get_trigger_slope(self):
        """Returns the trigger slope either POS or NEG"""
        slope=self.query(":TRIG:SLOP?")
        return slope

# %%
oscope=HighSpeedOscope("GPIB0::7")
# Out:
# The information sheet was not found defaulting to address

# %%
oscope.get_error_state()
# Out:
# u'-113,Undefined header\n'

# %%
oscope.get_timebase_scale()
# Out:
# 1.0

# %%
print oscope.get_number_points()
oscope.set_number_points(number_points=300)
print oscope.get_number_points()
# Out:
# 300
# 300

# %%
oscope.get_time_position()
# Out:
# 50.0

# %%
table=oscope.measure_waves(timeout_measurement=10000)
# Out:
# 1000
# 4
# len(frames_data) is1
# len(frames_data[0]) is4
# len(frames_data[0][0]) is1000
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([0], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([1], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([2], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([3], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([4], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([5], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([6], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([7], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([8], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([9], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([10], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([11], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([12], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([13], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([14], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([15], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([16], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([17], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([18], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([19], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([20], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([21], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([22], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([23], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([24], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([25], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([26], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([27], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([28], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([29], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([30], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([31], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([32], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([33], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([34], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([35], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([36], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([37], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([38], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([39], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([40], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([41], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([42], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([43], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([44], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([45], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([46], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([47], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([48], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([49], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([50], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([51], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([52], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([53], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([54], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([55], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([56], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([57], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([58], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([59], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([60], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([61], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([62], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([63], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([64], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([65], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([66], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([67], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([68], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([69], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([70], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([71], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([72], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([73], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([74], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([75], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([76], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([77], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([78], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([79], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([80], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([81], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([82], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([83], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([84], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([85], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([86], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([87], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([88], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([89], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([90], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([91], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([92], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([93], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([94], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([95], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([96], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([97], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([98], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([99], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([100], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([101], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([102], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([103], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([104], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([105], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([106], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([107], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([108], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([109], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([110], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([111], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([112], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([113], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([114], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([115], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([116], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([117], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([118], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([119], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([120], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([121], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([122], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([123], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([124], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([125], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([126], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([127], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([128], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([129], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([130], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([131], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([132], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([133], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([134], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([135], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([136], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([137], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([138], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([139], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([140], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([141], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([142], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([143], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([144], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([145], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([146], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([147], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([148], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([149], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([150], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([151], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([152], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([153], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([154], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([155], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([156], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([157], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([158], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([159], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([160], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([161], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([162], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([163], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([164], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([165], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([166], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([167], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([168], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([169], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([170], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([171], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([172], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([173], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([174], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([175], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([176], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([177], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([178], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([179], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([180], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([181], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([182], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([183], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([184], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([185], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([186], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([187], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([188], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([189], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([190], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([191], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([192], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([193], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([194], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([195], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([196], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([197], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([198], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([199], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([200], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([201], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([202], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([203], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([204], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([205], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([206], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([207], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([208], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([209], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([210], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([211], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([212], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([213], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([214], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([215], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([216], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([217], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([218], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([219], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([220], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([221], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([222], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([223], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([224], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([225], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([226], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([227], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([228], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([229], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([230], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([231], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([232], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([233], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([234], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([235], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([236], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([237], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([238], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([239], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([240], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([241], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([242], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([243], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([244], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([245], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([246], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([247], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([248], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([249], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([250], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([251], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([252], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([253], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([254], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([255], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([256], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([257], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([258], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([259], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([260], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([261], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([262], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([263], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([264], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([265], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([266], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([267], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([268], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([269], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([270], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([271], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([272], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([273], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([274], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([275], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([276], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([277], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([278], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([279], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([280], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([281], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([282], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([283], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([284], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([285], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([286], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([287], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([288], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([289], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([290], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([291], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([292], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([293], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([294], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([295], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([296], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([297], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([298], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([299], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([300], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([301], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([302], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([303], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([304], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([305], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([306], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([307], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([308], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([309], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([310], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([311], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([312], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([313], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([314], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([315], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([316], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([317], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([318], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([319], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([320], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([321], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([322], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([323], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([324], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([325], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([326], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([327], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([328], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([329], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([330], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([331], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([332], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([333], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([334], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([335], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([336], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([337], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([338], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([339], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([340], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([341], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([342], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([343], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([344], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([345], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([346], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([347], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([348], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([349], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([350], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([351], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([352], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([353], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([354], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([355], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([356], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([357], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([358], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([359], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([360], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([361], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([362], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([363], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([364], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([365], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([366], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([367], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([368], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([369], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([370], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([371], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([372], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([373], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([374], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([375], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([376], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([377], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([378], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([379], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([380], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([381], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([382], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([383], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([384], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([385], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([386], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([387], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([388], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([389], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([390], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([391], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([392], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([393], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([394], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([395], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([396], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([397], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([398], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([399], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([400], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([401], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([402], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([403], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([404], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([405], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([406], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([407], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([408], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([409], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([410], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([411], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([412], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([413], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([414], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([415], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([416], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([417], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([418], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([419], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([420], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([421], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([422], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([423], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([424], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([425], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([426], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([427], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([428], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([429], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([430], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([431], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([432], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([433], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([434], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([435], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([436], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([437], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([438], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([439], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([440], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([441], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([442], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([443], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([444], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([445], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([446], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([447], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([448], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([449], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([450], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([451], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([452], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([453], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([454], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([455], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([456], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([457], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([458], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([459], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([460], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([461], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([462], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([463], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([464], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([465], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([466], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([467], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([468], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([469], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([470], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([471], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([472], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([473], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([474], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([475], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([476], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([477], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([478], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([479], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([480], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([481], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([482], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([483], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([484], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([485], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([486], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([487], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([488], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([489], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([490], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([491], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([492], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([493], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([494], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([495], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([496], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([497], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([498], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([499], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([500], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([501], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([502], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([503], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([504], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([505], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([506], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([507], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([508], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([509], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([510], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([511], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([512], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([513], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([514], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([515], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([516], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([517], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([518], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([519], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([520], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([521], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([522], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([523], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([524], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([525], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([526], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([527], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([528], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([529], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([530], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([531], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([532], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([533], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([534], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([535], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([536], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([537], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([538], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([539], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([540], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([541], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([542], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([543], [0], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([544], [0], [0])
# ...
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([819], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([820], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([821], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([822], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([823], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([824], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([825], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([826], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([827], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([828], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([829], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([830], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([831], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([832], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([833], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([834], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([835], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([836], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([837], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([838], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([839], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([840], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([841], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([842], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([843], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([844], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([845], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([846], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([847], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([848], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([849], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([850], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([851], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([852], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([853], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([854], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([855], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([856], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([857], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([858], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([859], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([860], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([861], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([862], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([863], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([864], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([865], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([866], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([867], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([868], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([869], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([870], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([871], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([872], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([873], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([874], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([875], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([876], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([877], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([878], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([879], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([880], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([881], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([882], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([883], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([884], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([885], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([886], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([887], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([888], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([889], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([890], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([891], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([892], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([893], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([894], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([895], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([896], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([897], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([898], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([899], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([900], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([901], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([902], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([903], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([904], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([905], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([906], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([907], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([908], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([909], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([910], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([911], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([912], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([913], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([914], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([915], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([916], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([917], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([918], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([919], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([920], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([921], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([922], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([923], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([924], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([925], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([926], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([927], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([928], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([929], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([930], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([931], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([932], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([933], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([934], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([935], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([936], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([937], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([938], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([939], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([940], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([941], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([942], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([943], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([944], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([945], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([946], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([947], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([948], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([949], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([950], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([951], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([952], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([953], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([954], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([955], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([956], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([957], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([958], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([959], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([960], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([961], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([962], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([963], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([964], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([965], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([966], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([967], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([968], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([969], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([970], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([971], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([972], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([973], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([974], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([975], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([976], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([977], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([978], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([979], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([980], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([981], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([982], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([983], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([984], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([985], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([986], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([987], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([988], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([989], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([990], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([991], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([992], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([993], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([994], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([995], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([996], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([997], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([998], [3], [0])
# ([row_index+frame_index*number_rows],[column_index],[frame_index]) is ([999], [3], [0])

# %%
oscope.resource.timeout

# %%
print len(table.data[1])
# Out:
# 5

# %%
print len(table.data)
# Out:
# 101

# %%
print table
# Out:
# Time,CHAN1,CHAN2,CHAN3,CHAN4
# 50.0  -924  -1342  -658  -1074
# 50.0099009901  -1368  -800  -1070  -1036
# 50.0198019802  -558  -366  -696  -1272
# 50.0297029703  -1118  -1316  -1070  -976
# 50.0396039604  -906  -990  -1976  -996
# 50.0495049505  -1310  -854  -1188  -1056
# 50.0594059406  -1946  -1070  -1936  -1488
# 50.0693069307  -828  -854  -2034  -1350
# 50.0792079208  -790  -1478  -1208  -976
# 50.0891089109  -1714  -1260  -1346  -1212
# 50.099009901  -770  -636  -1778  -1036
# 50.1089108911  -1870  -1180  -1090  -838
# 50.1188118812  -1098  -1152  -440  -760
# 50.1287128713  -1850  -772  -736  -1292
# 50.1386138614  -1618  -1016  -1050  -1114
# 50.1485148515  -404  -990  -794  -1428
# 50.1584158416  -732  -936  -1286  -1252
# 50.1683168317  96  -800  -658  -602
# 50.1782178218  -462  -718  -1168  -1016
# 50.1881188119  -1502  -1994  -1228  -1428
# 50.198019802  -1406  -582  -618  -800
# 50.2079207921  -366  -1560  -460  -740
# 50.2178217822  -1060  -880  -1738  -1016
# 50.2277227723  -866  -854  -362  -1252
# 50.2376237624  -1714  -1234  -1228  -1114
# 50.2475247525  -1098  -746  -992  -996
# 50.2574257426  -1290  -936  -1030  -1114
# 50.2673267327  -1290  -1044  -892  -1350
# 50.2772277228  -750  -1504  -500  -1114
# 50.2871287129  -1714  -1098  -186  -642
# 50.297029703  -964  -1070  -814  -1428
# 50.3069306931  -1040  -1152  -1522  -700
# 50.3168316832  -944  -1560  -912  -1272
# 50.3267326733  -1002  -962  -912  -1174
# 50.3366336634  -694  -120  -1248  -1488
# 50.3465346535  -2158  -1126  -1326  -878
# 50.3564356436  -982  -1234  -1168  -1074
# 50.3663366337  -2042  -1234  -1128  -1036
# 50.3762376238  -230  -636  -1050  -1548
# 50.3861386139  -1908  -446  -716  -1192
# 50.396039604  -1812  -690  -912  -938
# 50.4059405941  -1560  -880  -892  -1232
# 50.4158415842  -1734  -1504  -1228  -1074
# 50.4257425743  -538  -1070  -756  -918
# 50.4356435644  -1118  -1450  -1484  -1528
# 50.4455445545  -1812  -746  -972  -1330
# 50.4554455446  -1252  -1478  -1464  -838
# 50.4653465347  -1966  -1206  -1306  -1548
# 50.4752475248  -212  -908  -1090  -1192
# 50.4851485149  -1272  -636  -1208  -1174
# 50.495049505  -1078  -1830  -1228  -1074
# 50.504950495  -828  -1478  -1758  -818
# 50.5148514851  -1870  -880  -618  -1350
# 50.5247524752  -1348  -1288  -638  -938
# 50.5346534653  -230  -1016  -814  -1036
# 50.5445544554  -712  -1342  -912  -1330
# 50.5544554455  -1156  -1316  -304  -996
# 50.5643564356  -964  -990  -1838  -1428
# 50.5742574257  -1446  -800  -952  -976
# 50.5841584158  -1984  -338  -1286  -956
# 50.5940594059  232  -1316  -1188  -1114
# 50.603960396  -906  -880  -874  -1134
# 50.6138613861  -596  -962  -834  -818
# 50.6237623762  -384  -1450  -440  -1016
# 50.6336633663  -808  -746  -598  -1036
# 50.6435643564  -770  -1804  -834  -898
# 50.6534653465  -982  -1994  -440  -1094
# 50.6633663366  -578  -880  -912  -1252
# 50.6732673267  -308  -800  -834  -956
# 50.6831683168  -1812  -1070  -912  -858
# 50.6930693069  -424  -718  -1856  -564
# 50.702970297  -982  -690  -1128  -1056
# 50.7128712871  -520  -854  -1680  -1134
# 50.7227722772  -326  -1342  -716  -898
# 50.7326732673  -1252  -908  -774  -956
# 50.7425742574  -808  -1044  -1542  -898
# 50.7524752475  -3180  -1206  -658  -1114
# 50.7623762376  -808  -1478  -1306  -1056
# 50.7722772277  -712  -610  -992  -1192
# 50.7821782178  -1252  -392  -1050  -1094
# 50.7920792079  366  -1206  -1208  -976
# 50.801980198  -1388  -1234  -1070  -878
# 50.8118811881  -1060  -936  -618  -1448
# 50.8217821782  -1176  -772  -1266  -1074
# 50.8316831683  -1754  -582  -1050  -996
# 50.8415841584  -1618  -1016  -1798  -1292
# 50.8514851485  -2254  -1044  -460  -1056
# 50.8613861386  -538  -1424  -342  -996
# 50.8712871287  -1098  -854  -1444  -682
# 50.8811881188  -1272  -1316  -1050  -1174
# 50.8910891089  -964  -936  -1976  -1212
# 50.900990099  -2698  -1180  -244  -956
# 50.9108910891  -1194  -528  -618  -976
# 50.9207920792  -462  -690  -1660  -878
# 50.9306930693  -828  -1830  -126  -1370
# 50.9405940594  -1580  -1098  -1936  -1154
# 50.9504950495  -212  -1504  -972  -1330
# 50.9603960396  -172  -1450  -992  -938
# 50.9702970297  -520  -962  -1050  -800
# 50.9801980198  -1118  -772  -1306  -1134
# 50.9900990099  -828  -962  -874  -642

# %%
plt.plot(table["Time"],table["CHAN1"])
plt.show()

# %%
vna=VNA("GPIB::20")

# %%
vna.write("SOUR1:POW:STAT ON")
# Out:
# (19L, <StatusCode.success: 0>)

# %%
import math
math.sqrt(.05)
# Out:
# 0.22360679774997896

# %%
vna.write("SOUR1:FREQ{0} {1}".format(1,10**9))
# Out:
# (24L, <StatusCode.success: 0>)

# %%
math.sqrt(50*100*10**-6)
# Out:
# 0.07071067811865475

# %%
vna.set_power(-10)

# %%
vna.get_power()
# Out:
# u'0\n'

# %%
pm=NRPPowerMeter("GPIB::14")

# %%
pm.initialize()

# %%
pm.get_reading()
# Out:
# 2.709479e-07

# %%
vna.initialize()

# %%
out=oscope.measure_waves(channels=[3,4])
# Out:
# ---------------------------------------------------------------------------
# VisaIOError                               Traceback (most recent call last)
# <ipython-input-111-b3854ecad181> in <module>()
# ----> 1 out=oscope.measure_waves(channels=[3,4])
#
# <ipython-input-77-275775a08d73> in measure_waves(self, **options)
#      75                 self.write(':WAV:SOUR CHAN{0}'.format(channel_read))
#      76                 # get data
# ---> 77                 data_column=self.resource.query_binary_values(':WAV:DATA?', datatype='h')
#      78                 new_frame.append(data_column)
#      79                 #print("{0} is {1}".format("data_column",data_column))
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyvisa\resources\messagebased.pyc in query_binary_values(self, message, datatype, is_big_endian, container, delay, header_fmt)
#     479             time.sleep(delay)
#     480
# --> 481         block = self.read_raw()
#     482
#     483         if header_fmt == 'ieee':
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyvisa\resources\messagebased.pyc in read_raw(self, size)
#     304                     logger.debug('%s - reading %d bytes (last status %r)',
#     305                                  self._resource_name, size, status)
# --> 306                     chunk, status = self.visalib.read(self.session, size)
#     307                     ret += chunk
#     308             except errors.VisaIOError as e:
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyvisa\ctwrapper\functions.pyc in read(library, session, count)
#    1580     buffer = create_string_buffer(count)
#    1581     return_count = ViUInt32()
# -> 1582     ret = library.viRead(session, buffer, count, byref(return_count))
#    1583     return buffer.raw[:return_count.value], ret
#    1584
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyvisa\ctwrapper\highlevel.pyc in _return_handler(self, ret_value, func, arguments)
#     186
#     187         if ret_value < 0:
# --> 188             raise errors.VisaIOError(ret_value)
#     189
#     190         if ret_value in self.issue_warning_on:
#
# VisaIOError: VI_ERROR_TMO (-1073807339): Timeout expired before operation completed.
