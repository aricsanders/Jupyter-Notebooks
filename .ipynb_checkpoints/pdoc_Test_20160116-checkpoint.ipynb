# %% [markdown]
# # A test of <a href="http://pdoc.burntsushi.net/pdoc#pdoc.html">pdoc</a>
# ## This notebook demonstrates using pdoc to make a html documentation page
# ### Written by Aric Sanders, 01/2016

# %%
# import pdoc module
import pdoc

# %%
# pass the pdoc.html function a string with the module name
doc=pdoc.html('pyMeasure.Code.DataHandlers.Measurements')

# %%
print doc
# Out:
# <!doctype html>
# <head>
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1" />
#
#     <title>pyMeasure.Code.DataHandlers.Measurements API documentation</title>
#     <meta name="description" content="Measurements is a module that defines functions and classes to hold and
# manipulate measured data." />
#
#   <link href='http://fonts.googleapis.com/css?family=Source+Sans+Pro:400,300' rel='stylesheet' type='text/css'>
#
#   <style type="text/css">
#
# * {
#   box-sizing: border-box;
# }
# /*! normalize.css v1.1.1 | MIT License | git.io/normalize */
#
# /* ==========================================================================
#    HTML5 display definitions
#    ========================================================================== */
#
# /**
#  * Correct `block` display not defined in IE 6/7/8/9 and Firefox 3.
#  */
#
# article,
# aside,
# details,
# figcaption,
# ...

# %%
    def save(file_string,path):
        
        file_out=open(path,'w')
        file_out.write(file_string)
        file_out.close()

# %%
os.getcwd()
# Out:
# 'C:\\Users\\arics'

# %%
path=os.path.join(os.getcwd(),'/Documents/Measurements_Documentation.html')

# %%
save(doc,r'C:documentation.html')

# %%
doc=pdoc.text('pyMeasure.Code.DataHandlers.Measurements')
print doc
# Out:
# Module pyMeasure.Code.DataHandlers.Measurements
# -----------------------------------------------
# Measurements is a module that defines functions and classes to hold and
# manipulate measured data.
#
# Variables
# ---------
# DEFAULT_MEASUREMENT_XSL
#
# DEFAULT_STATE_XSL
#
# INSTRUMENT_TYPES
#
# MEASUREMENTS_DIRECTORY
#
# METHOD_ALIASES
#
# PYMEASURE_ROOT
#
# StringTypes
#
# XSLT_CAPABLE
#
# Functions
# ---------
# test_DataTable()
#     Test's the DataTable Class
#
# test_get_attribute_names(sheet_name='Data_Table_021711_22.xml')
#
# test_get_header()
#     Test of the get header function
#
# test_open_measurement(sheet_name='Data_Table_021711_22.xml')
#     Tests opening a sheet
#
# Classes
# -------
# DataTable
#     This is a XML data table class with an optional description
#
#     Ancestors (in MRO)
#     ------------------
#     pyMeasure.Code.DataHandlers.Measurements.DataTable
#
#     Instance variables
#     ------------------
#     general_descriptor
#
# ...
