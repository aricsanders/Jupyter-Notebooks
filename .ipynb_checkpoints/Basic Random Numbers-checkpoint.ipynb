# %% [markdown]
# <p id="random">
# <h2>Basic Random Number Generation and Printing in Python</h2>
# <a href="https://docs.python.org/2/library/random.html">Uses the random library</a><br/>
# <a href="http://docs.scipy.org/doc/numpy/reference/routines.statistics.html"> Also uses numpy for stats</a><br/>
# </p>

# %%
import random
import numpy as np
random_list=np.array([random.gauss(1,.1) for i in range(10)])
print random_list #raw print, notice it sucks for cut and paste
print '*'*100 #simple way to make a line of characters
print np.array_str(random_list, precision=2)# printing without commas, but with a specified precision
print '_'*100
print(map(lambda x:float("{:.2f}".format(x)),random_list))#printing with commas for cut and paste  with a specific format
print '-'*100
print '/'*100
# Out:
# [ 0.89242481  1.10086919  0.94397648  0.97195534  0.95054309  1.13474553
#   0.90770127  0.90308499  1.0396366   0.87415054]
# ****************************************************************************************************
# [ 0.89  1.1   0.94  0.97  0.95  1.13  0.91  0.9   1.04  0.87]
# ____________________________________________________________________________________________________
# [0.89, 1.1, 0.94, 0.97, 0.95, 1.13, 0.91, 0.9, 1.04, 0.87]
# ----------------------------------------------------------------------------------------------------
# ////////////////////////////////////////////////////////////////////////////////////////////////////

# %%
test_list=[1,2,3,4,5,6]
print sum(map(lambda x:ord(x),'MYSeed'))
#np.random.seed([1234])
print np.random.permutation(test_list)
# Out:
# 551
# [6 3 2 5 4 1]

# %%
dir(np.random)
# Out:
# ['Lock',
#  'RandomState',
#  'Tester',
#  '__RandomState_ctor',
#  '__all__',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__warningregistry__',
#  'absolute_import',
#  'bench',
#  'beta',
#  'binomial',
#  'bytes',
#  'chisquare',
#  'choice',
#  'dirichlet',
#  'division',
#  'exponential',
#  'f',
#  'gamma',
#  'geometric',
#  'get_state',
#  'gumbel',
#  'hypergeometric',
#  'info',
#  'laplace',
#  'logistic',
#  'lognormal',
#  'logseries',
#  'mtrand',
#  'multinomial',
#  'multivariate_normal',
#  'negative_binomial',
#  'noncentral_chisquare',
#  'noncentral_f',
#  'normal',
#  'np',
#  'operator',
#  'pareto',
#  'permutation',
#  'poisson',
#  'power',
#  'print_function',
#  'rand',
#  'randint',
#  'randn',
#  'random',
#  'random_integers',
#  'random_sample',
#  'ranf',
#  'rayleigh',
#  'sample',
#  'seed',
#  'set_state',
#  'shuffle',
#  'standard_cauchy',
#  'standard_exponential',
#  'standard_gamma',
#  'standard_normal',
#  'standard_t',
#  'test',
#  'triangular',
#  'uniform',
#  'vonmises',
#  'wald',
#  'warnings',
#  'weibull',
#  'zipf']

# %%
# %matplotlib notebook
mu, kappa = 0.0, 4.0 # mean and dispersion
s = np.random.vonmises(mu, kappa, 1000)
import matplotlib.pyplot as plt
from scipy.special import i0
plt.hist(s, 50, normed=True)
x = np.linspace(-np.pi, np.pi, num=51)
y = np.exp(kappa*np.cos(x-mu))/(2*np.pi*i0(kappa))
plt.plot(x, y, linewidth=2, color='r')
plt.show()
# Out:
# <img src="data:image/png;base64,...">
