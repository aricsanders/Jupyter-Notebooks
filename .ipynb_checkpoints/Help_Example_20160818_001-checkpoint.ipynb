# %% [markdown]
# # Example of how to create a html help page given a function or class name

# %%
from pyMeasure.Code.Utils.HelpUtils import create_help_page,return_help
from pyMeasure.Code.Utils.PerformanceUtils import timer
import inspect
import re
from pyMeasure import *

# %%
globals()
# Out:
# {'ACTIVE_COMPONENTS': [1, 1, 1],
#  'ARRAY': <function ctypes.ARRAY>,
#  'AdvancedInterfaceFrame': <module 'pyMeasure.Code.FrontEnds.AdvancedInterfaceFrame' from 'C:\Anaconda2\lib\site-packages\pyMeasure\Code\FrontEnds\AdvancedInterfaceFrame.pyc'>,
#  'ArgumentError': ctypes.ArgumentError,
#  'Array': _ctypes.Array,
#  'AsciiDataTable': <class pyMeasure.Code.DataHandlers.GeneralModels.AsciiDataTable at 0x0000000004221288>,
#  'AsciiDataTableCollection': <class pyMeasure.Code.DataHandlers.GeneralModels.AsciiDataTableCollection at 0x00000000042212E8>,
#  'AsciiDataTable_to_DataFrame': <function pyMeasure.Code.DataHandlers.Translations.AsciiDataTable_to_DataFrame>,
#  'AsciiDataTable_to_Excel': <function pyMeasure.Code.DataHandlers.Translations.AsciiDataTable_to_Excel>,
#  'AsciiDataTable_to_XMLDataTable': <function pyMeasure.Code.DataHandlers.Translations.AsciiDataTable_to_XMLDataTable>,
#  'BigEndianStructure': ctypes._endian.BigEndianStructure,
#  'BooleanType': bool,
# ...

# %%
mod=inspect.getmodule(XMLBase)
mod.__name__

# %%
@timer
def return_help2(object):
    return return_help(object)
help_html=return_help2(XMLBase)
# Out:
# The function return_help2 started at 2016-08-18 22:26:43.570000 and ended at 2016-08-18 22:26:44.526000
# It took 0.956 seconds to run

# %%
from IPython.display import HTML,display

# %%
display(HTML(help_html))
# Out:
# <!doctype html>
# <head>
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1" />
#
#     <title>pyMeasure.Code.DataHandlers.XMLModels API documentation</title>
#     <meta name="description" content="XMLModels is dedicated to handling xml based models,
# requires lxml to be installed." />
#
#   <link href='http://fonts.googleapis.com/css?family=Source+Sans+Pro:400,300' rel='stylesheet' type='text/css'>
#
#   <style type="text/css">
#
# * {
#   box-sizing: border-box;
# }
# /*! normalize.css v1.1.1 | MIT License | git.io/normalize */
#
# /* ==========================================================================
#    HTML5 display definitions
#    ========================================================================== */
#
# /**
#  * Correct `block` display not defined in IE 6/7/8/9 and Firefox 3.
#  */
#
# article,
# aside,
# details,
# figcaption,
# figure,
# footer,
# ...

# %%
help(XMLBase)
# Out:
# Help on class XMLBase in module pyMeasure.Code.DataHandlers.XMLModels:
#
# class XMLBase
#  |  The XMLBase Class is designed to be a container for xml data
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, file_path=None, **options)
#  |      Initializes the XML Base Class
#  |
#  |  __str__(self)
#  |      Controls how XMLBAse is returned when a string function is called
#  |
#  |  save(self, path=None)
#  |      " Saves as an XML file
#  |
#  |  save_HTML(self, XSLT=None, file_path=None)
#  |      Saves a HTML transformation of the XML document using XLST at file_path. Defaults to
#  |      an XLST in self.options["XSLT"] and file_path=self.path.replace('.xml','.html')
#  |
#  |  show(self, mode='Window')
#  |      Displays a XML Document either as formatted text in the command line or in a
#  |      window (using wx)
#  |
#  |  to_HTML(self, XSLT=None)
#  |      Returns HTML string by applying a XSL to the XML document
