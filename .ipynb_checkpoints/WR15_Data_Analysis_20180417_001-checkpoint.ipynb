# %%
from pyMez import *
from pyMez.Code.Analysis.SParameter import *
from pyMez.Code.DataHandlers.MUFModels import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 3.268 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.538 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# It took 6.035 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# It took 0.004 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.134 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.011 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# It took 0.71 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.006 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.006 s to import Code.Utils.Names
# ...

# %%
schema=read_schema(r"C:\Share\WR15_OML_20180309\Line5079\w2p\Line_5079_WR15_Wave_Parameters_20180313_001.schema")
for key,value in schema.iteritems():
    print("{0}:{1}".format(key,value))
# Out:
# Measurement_Timestamp:2018-03-13 20:03:34.308000
# inline_comments:None
# data_begin_line:1
# column_names_begin_line:0
# footer_line_types:None
# general_descriptor:Two_Port
# specific_descriptor:Wave_Parameters
# header_end_line:None
# column_names_end_line:1
# data_table_element_separator:
#
# escape_character:None
# inline_comment_begin:None
# column_descriptions:None
# Power:-10
#
# inline_comment_end:None
# IFBW:10.0
# data_list_dictionary:None
# data_begin_token:None
# comment_end:None
# header_begin_line:None
# row_end_token:None
# block_comment_begin:None
# column_units:None
# metadata:None
# header_end_token:None
# comment_begin:None
# empty_value:None
# column_names_begin_token:!
# footer_end_token:None
# footer_begin_token:None
# column_names_delimiter:,
# metadata_key_value_delimiter:None
# column_types:['float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float', 'float']
# data:None
# ...

# %%
s2p_name_list=[r"C:\Share\WR15_OML_MUF_20180313\LRL_1\DUTs\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_Support\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_0.s2p",
              r"C:\Share\WR15_OML_MUF_20180313\MTRL_1\DUTs\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_Support\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_0.s2p",
              r"C:\Share\WR15_OML_MUF_20180313\MTRL_2\DUTs\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_Support\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_0.s2p",
              r"C:\Share\WR15_OML_MUF_20180313\SOLT_1\DUTs\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_Support\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_0.s2p",
              r"C:\Share\WR15_OML_MUF_20180313\TRL_1\DUTs\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_Support\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_0.s2p",
              r"C:\Share\WR15_VDI_MUF_20180316\LRL_1\DUTs\Match_10015_P1_FixedLoad_70020_P2_WR15_20180223_001_Support\Match_10015_P1_FixedLoad_70020_P2_WR15_20180223_001_0.s2p"]
s2p_list=[SNP(name) for name in s2p_name_list]

# %%
compare_s2p_plots(s2p_list,labels=["LRL","ML TRL 1","ML TRL 2","SOLT "," TRL"," VDI TRL"])

# %%
s2p_name_list=[r"C:\Share\WR15_OML_MUF_20180313\LRL_1\DUTs\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_Support\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_0.s2p",
              r"C:\Share\WR15_OML_MUF_20180313\MTRL_1\DUTs\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_Support\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_0.s2p",
              r"C:\Share\WR15_OML_MUF_20180313\MTRL_2\DUTs\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_Support\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_0.s2p",
              r"C:\Share\WR15_OML_MUF_20180313\SOLT_1\DUTs\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_Support\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_0.s2p",
              r"C:\Share\WR15_OML_MUF_20180313\TRL_1\DUTs\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_Support\RS_Match_100015_P1_Keysight_FixedLoad_70020_P2_WR15_20180313_001_0.s2p",
              r"C:\Share\WR15_VDI_MUF_20180316\LRL_1\DUTs\Match_10015_P1_FixedLoad_70020_P2_WR15_20180223_001_Support\Match_10015_P1_FixedLoad_70020_P2_WR15_20180223_001_0.s2p"]
s2p_list=[SNP(name) for name in s2p_name_list]
compare_s2p_plots(s2p_list,labels=["LRL","ML TRL 1","ML TRL 2","SOLT "," TRL"," VDI TRL"])
