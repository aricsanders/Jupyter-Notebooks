# %%
from pyMez import *
from Code.Analysis.SParameter import *

# %%
summary_directory=r"C:\Share\AWG_Phase_Calibration\Summary_Files\Zero_Phase"
summary_file_names=[]
for file_name in os.listdir(summary_directory):
    if re.search("txt",file_name):
        summary_file_names.append(file_name)
summary_file_names=map(lambda x: os.path.join(summary_directory,x),summary_file_names)
summary_files=map(lambda x: AsciiDataTable(x,**read_schema(change_extension(x,new_extension="schema"))),summary_file_names)

# %%
summary_files[0]

# %%
def plot_all_tones(summary_file_model):
    """Plots the measured phase against the AWG set phase for all tones in the summary file"""
    for tone_index in range(11):
        start_index=tone_index*(10)
        stop_index=tone_index*(10)+10
        x_data=summary_file_model["AWG_Set_Phase"][start_index:stop_index]
        #corrected_list=360+np.array(summary["Vna_Phase"][8:10])
        vna_data=summary_file_model["Vna_Phase"][start_index:stop_index]
        #corrected_scope_list=180+np.array(summary["Scope_Phase"][5:10])
        scope_data=summary_file_model["Scope_Phase"][start_index:stop_index]
        plt.plot(x_data,vna_data,'bo',label="VNA")
        plt.plot(x_data,scope_data,'r^',label="Oscilloscope")
        #plt.plot(x_data,summary_file_model["Vna_Comb_Referenced_Phase"][start_index:stop_index],'gs',label="VNA Comb Reference")
        plt.legend()
        plt.xlabel("AWG Set Phase (Degrees)")
        plt.ylabel("Measured Phase (Degrees)")
        plt.title(r"$Tone : {0}/11, F_0 = 1 GHz, \Delta F={1:.1e} Hz$".format(tone_index+1,summary_file_model.metadata["tone_spacing"]))
        #plt.savefig(r'Q:\public\Aric\AWG_Phase_Calibration_20180927\11_Tones_10000000000KHz_Spacing\{0}_{1}.png'.format(format(tone_index+1)))
        plt.show()

# %%
plot_all_tones(summary_files[0])

# %%
summary_files[1].metadata
# Out:
# {'Timestamp': '2018-10-05 15:31:30.662000',
#  'frequnecy_list': [987500000.0,
#   990000000.0,
#   992500000.0,
#   995000000.0,
#   997500000.0,
#   1000000000.0,
#   1002500000.0,
#   1005000000.0,
#   1007500000.0,
#   1010000000.0,
#   1012500000.0],
#  'multisine_phase': 'zero',
#  'number_harmonics': 1,
#  'number_tones': 11,
#  'sweep': '11_Tones_2500000000KHz_Spacing',
#  'tone_spacing': 2500000.0}

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-b1e9a3971c5f> in <module>()
# ----> 1 print [value-summary_files[0]["Scope_Phase"][i] for i,value in enumerate(summary_files[0][1:])]
#
# C:\ProgramData\Anaconda2\lib\site-packages\pyMez\Code\DataHandlers\GeneralModels.pyc in __getitem__(self, items)
#    1734             return self.get_column(items)
#    1735         else:
# -> 1736             for item in items:
#    1737                 if type(item) is IntType:
#    1738                     column_selectors.append(item)
#
# TypeError: 'slice' object is not iterable

# %%
def fix_phase(phase_list):
    
    last_phase=phase_list[0]
    new_phase_list=[last_phase]
    for phase in phase_list[1:]:
        phase_offset=phase-last_phase
        #print("Phase Offset is {0}".format(phase_offset))
        if 90<phase_offset<270:

            new_phase=phase-180
        elif -90>phase_offset>-270:
            new_phase=phase+180
        elif -270>phase_offset:
            new_phase=phase+360
        else:
            new_phase=phase
        #print(" New Phase is {0}, Old Phase is {1}".format(new_phase,phase))
        new_phase_list.append(new_phase)
        last_phase=new_phase
    return new_phase_list

# %%
plt.plot(summary_files[0]["Scope_Phase"])
plt.plot(fix_phase(summary_files[0]["Scope_Phase"]))
plt.show()
# Out:
# Phase Offset is 36.0087929833
#  New Phase is -32.3167643891, Old Phase is -32.3167643891
# Phase Offset is 36.0168590473
#  New Phase is 3.7000946582, Old Phase is 3.7000946582
# Phase Offset is 36.0935368723
#  New Phase is 39.7936315305, Old Phase is 39.7936315305
# Phase Offset is 35.8443484014
#  New Phase is 75.6379799319, Old Phase is 75.6379799319
# Phase Offset is -143.920563736
#  New Phase is 111.717416196, Old Phase is -68.2825838037
# Phase Offset is -143.912935243
#  New Phase is 147.804480954, Old Phase is -32.1955190464
# Phase Offset is -143.896280573
#  New Phase is 183.90820038, Old Phase is 3.90820038022
# Phase Offset is -143.996222119
#  New Phase is 219.911978261, Old Phase is 39.9119782612
# Phase Offset is -143.911380353
#  New Phase is 256.000597908, Old Phase is 76.0005979084
# Phase Offset is -344.501184166
#  New Phase is 271.499413742, Old Phase is -88.5005862578
# Phase Offset is -324.124724496
#  New Phase is 307.374689246, Old Phase is -52.6253107535
# Phase Offset is -323.94572986
#  New Phase is 343.428959387, Old Phase is -16.5710406131
# Phase Offset is -323.918531848
#  New Phase is 379.510427539, Old Phase is 19.5104275393
# Phase Offset is -323.843942182
#  New Phase is 415.666485358, Old Phase is 55.6664853576
# Phase Offset is -504.04163299
#  New Phase is 271.624852367, Old Phase is -88.3751476327
# Phase Offset is -324.127044718
#  New Phase is 307.497807649, Old Phase is -52.5021923509
# Phase Offset is -324.0130695
#  New Phase is 343.48473815, Old Phase is -16.5152618505
# Phase Offset is -323.819867888
#  New Phase is 379.664870262, Old Phase is 19.6648702618
# Phase Offset is -324.036946882
#  New Phase is 415.62792338, Old Phase is 55.6279233796
# Phase Offset is -343.194335016
#  New Phase is 432.433588364, Old Phase is 72.4335883636
# Phase Offset is -504.137800735
#  New Phase is 288.295787629, Old Phase is -71.704212371
# Phase Offset is -324.04758811
#  New Phase is 324.248199519, Old Phase is -35.7518004812
# Phase Offset is -323.944327544
#  New Phase is 360.303871975, Old Phase is 0.303871975031
# Phase Offset is -324.095693812
#  New Phase is 396.208178163, Old Phase is 36.208178163
# Phase Offset is -323.89514487
#  New Phase is 432.313033293, Old Phase is 72.313033293
# Phase Offset is -504.12691472
#  New Phase is 288.186118573, Old Phase is -71.8138814274
# Phase Offset is -323.920654452
#  New Phase is 324.265464121, Old Phase is -35.734535879
# Phase Offset is -323.938179846
#  New Phase is 360.327284275, Old Phase is 0.327284274932
# Phase Offset is -323.841084862
#  New Phase is 396.486199413, Old Phase is 36.4861994127
# Phase Offset is -342.141610946
#  New Phase is 414.344588467, Old Phase is 54.3445884671
# Phase Offset is -504.105888572
#  New Phase is 270.238699895, Old Phase is -89.7613001053
# Phase Offset is -324.037662111
#  New Phase is 306.201037783, Old Phase is -53.7989622166
# Phase Offset is -324.112691987
#  New Phase is 342.088345796, Old Phase is -17.9116542037
# Phase Offset is -324.027032258
#  New Phase is 378.061313539, Old Phase is 18.0613135387
# Phase Offset is -323.891455457
#  New Phase is 414.169858082, Old Phase is 54.1698580818
# Phase Offset is -503.941860789
#  New Phase is 270.227997293, Old Phase is -89.7720027073
# Phase Offset is -324.04432782
#  New Phase is 306.183669472, Old Phase is -53.8163305276
# Phase Offset is -324.299118205
#  New Phase is 341.884551267, Old Phase is -18.1154487327
# Phase Offset is -323.84889404
#  New Phase is 378.035657227, Old Phase is 18.0356572273
# Phase Offset is -342.858288424
#  New Phase is 395.177368803, Old Phase is 35.1773688029
# Phase Offset is -323.885498577
#  New Phase is 431.291870226, Old Phase is 71.2918702259
# Phase Offset is -504.046047937
#  New Phase is 287.245822289, Old Phase is -72.7541777107
# Phase Offset is -324.021081325
#  New Phase is 323.224740965, Old Phase is -36.7752590354
# Phase Offset is -324.07903646
#  New Phase is 359.145704505, Old Phase is -0.854295494939
# Phase Offset is -323.978285414
#  New Phase is 395.167419091, Old Phase is 35.1674190908
# Phase Offset is -324.08119383
#  New Phase is 431.086225261, Old Phase is 71.0862252611
# Phase Offset is -503.992330569
#  New Phase is 287.093894693, Old Phase is -72.9061053074
# Phase Offset is -323.955830147
#  New Phase is 323.138064546, Old Phase is -36.8619354542
# Phase Offset is -324.001576223
#  New Phase is 359.136488322, Old Phase is -0.8635116777
# Phase Offset is -344.246797511
#  New Phase is 374.889690811, Old Phase is 14.8896908109
# Phase Offset is -324.141622275
#  New Phase is 410.748068536, Old Phase is 50.7480685359
# Phase Offset is -323.82210813
#  New Phase is 446.925960406, Old Phase is 86.9259604061
# Phase Offset is -504.021121913
#  New Phase is 302.904838493, Old Phase is -57.0951615067
# Phase Offset is -323.865154658
#  New Phase is 339.039683835, Old Phase is -20.9603161648
# Phase Offset is -324.064039723
#  New Phase is 374.975644112, Old Phase is 14.9756441121
# Phase Offset is -323.964578078
#  New Phase is 411.011066034, Old Phase is 51.011066034
# Phase Offset is -323.997774251
#  New Phase is 447.013291783, Old Phase is 87.0132917828
# Phase Offset is -503.97850911
#  New Phase is 303.034782673, Old Phase is -56.965217327
# Phase Offset is -323.996222704
#  New Phase is 339.038559969, Old Phase is -20.9614400314
# Phase Offset is -343.711110022
#  New Phase is 355.327449947, Old Phase is -4.67255005339
# Phase Offset is -324.271947394
#  New Phase is 391.055502553, Old Phase is 31.0555025526
# Phase Offset is -324.108566171
#  New Phase is 426.946936382, Old Phase is 66.9469363818
# Phase Offset is -503.941557366
#  New Phase is 283.005379016, Old Phase is -76.9946209842
# Phase Offset is -324.012104478
#  New Phase is 318.993274538, Old Phase is -41.0067254617
# Phase Offset is -323.797723903
#  New Phase is 355.195550635, Old Phase is -4.80444936455
# Phase Offset is -324.10802626
#  New Phase is 391.087524375, Old Phase is 31.087524375
# Phase Offset is -324.10667922
#  New Phase is 426.980845155, Old Phase is 66.9808451549
# Phase Offset is -503.930685533
#  New Phase is 283.050159622, Old Phase is -76.9498403781
# Phase Offset is -323.928999
#  New Phase is 319.121160622, Old Phase is -40.8788393782
# Phase Offset is -343.055479837
#  New Phase is 336.065680785, Old Phase is -23.934319215
# Phase Offset is -324.021455479
#  New Phase is 372.044225305, Old Phase is 12.0442253055
# Phase Offset is -324.255587886
#  New Phase is 407.788637419, Old Phase is 47.788637419
# Phase Offset is -324.09813595
#  New Phase is 443.690501469, Old Phase is 83.6905014694
# Phase Offset is -504.000934867
#  New Phase is 299.689566603, Old Phase is -60.3104333975
# Phase Offset is -323.93567526
#  New Phase is 335.753891342, Old Phase is -24.2461086579
# Phase Offset is -323.863702218
#  New Phase is 371.890189124, Old Phase is 11.8901891238
# Phase Offset is -324.295073258
#  New Phase is 407.595115866, Old Phase is 47.595115866
# Phase Offset is -323.992734381
#  New Phase is 443.602381485, Old Phase is 83.6023814845
# Phase Offset is -503.973518343
#  New Phase is 299.628863142, Old Phase is -60.3711368581
# Phase Offset is -342.995273512
#  New Phase is 316.63358963, Old Phase is -43.3664103704
# Phase Offset is -323.866911695
#  New Phase is 352.766677935, Old Phase is -7.23332206539
# Phase Offset is -323.930255232
#  New Phase is 388.836422702, Old Phase is 28.8364227024
# Phase Offset is -324.057471993
#  New Phase is 424.77895071, Old Phase is 64.7789507095
# Phase Offset is -504.145887078
#  New Phase is 280.633063632, Old Phase is -79.3669363685
# Phase Offset is -323.959547976
#  New Phase is 316.673515656, Old Phase is -43.3264843444
# Phase Offset is -323.767553777
#  New Phase is 352.905961878, Old Phase is -7.09403812188
# Phase Offset is -324.163748841
#  New Phase is 388.742213037, Old Phase is 28.7422130374
# Phase Offset is -324.068926098
#  New Phase is 424.67328694, Old Phase is 64.6732869399
# Phase Offset is -504.059059983
#  New Phase is 280.614226957, Old Phase is -79.3857730431
# Phase Offset is -343.772720819
#  New Phase is 296.841506138, Old Phase is -63.1584938617
# Phase Offset is -323.920935446
#  New Phase is 332.920570692, Old Phase is -27.0794293081
# Phase Offset is -324.018582235
#  New Phase is 368.901988457, Old Phase is 8.90198845684
# Phase Offset is -323.989023017
#  New Phase is 404.912965439, Old Phase is 44.9129654395
# Phase Offset is -324.135153124
#  New Phase is 440.777812316, Old Phase is 80.7778123159
# Phase Offset is -503.957430084
#  New Phase is 296.820382232, Old Phase is -63.1796177676
# Phase Offset is -323.831925981
#  New Phase is 332.988456252, Old Phase is -27.0115437483
# Phase Offset is -323.94234976
#  New Phase is 369.046106492, Old Phase is 9.04610649172
# Phase Offset is -323.824705682
#  New Phase is 405.221400809, Old Phase is 45.2214008094
# Phase Offset is -324.274910173
#  New Phase is 440.946490636, Old Phase is 80.9464906364
# Phase Offset is -524.243919122
#  New Phase is 276.702571515, Old Phase is -83.2974284853
# Phase Offset is -324.287728596
#  New Phase is 312.414842918, Old Phase is -47.5851570815
# Phase Offset is -323.937986654
#  New Phase is 348.476856265, Old Phase is -11.5231437353
# Phase Offset is -323.732456982
#  New Phase is 384.744399282, Old Phase is 24.7443992824
# Phase Offset is -323.945169143
#  New Phase is 420.799230139, Old Phase is 60.799230139
# Phase Offset is -504.185368295
#  New Phase is 276.613861844, Old Phase is -83.3861381557
# Phase Offset is -323.987220145
#  New Phase is 312.626641699, Old Phase is -47.3733583008
# Phase Offset is -324.070860752
#  New Phase is 348.555780948, Old Phase is -11.4442190524
# Phase Offset is -323.832341506
#  New Phase is 384.723439441, Old Phase is 24.7234394412
# Phase Offset is -323.927529143
#  New Phase is 420.795910298, Old Phase is 60.795910298

# %%
def plot_all_tones_fix_phase(summary_file_model):
    """Plots the measured phase against the AWG set phase for all tones in the summary file"""
    for tone_index in range(11):
        start_index=tone_index*(10)
        stop_index=tone_index*(10)+10
        x_data=summary_file_model["AWG_Set_Phase"][start_index:stop_index]
        #corrected_list=360+np.array(summary["Vna_Phase"][8:10])
        vna_data=fix_phase(summary_file_model["Vna_Phase"][start_index:stop_index])
        #corrected_scope_list=180+np.array(summary["Scope_Phase"][5:10])
        scope_data=fix_phase(summary_file_model["Scope_Phase"][start_index:stop_index])
        plt.plot(x_data,vna_data,'bo',label="VNA")
        plt.plot(x_data,scope_data,'r^',label="Oscilloscope")
        plt.plot(x_data,summary_file_model["Vna_Comb_Referenced_Phase"][start_index:stop_index],'gs',label="VNA Comb Reference")
        plt.legend()
        plt.xlabel("AWG Set Phase (Degrees)")
        plt.ylabel("Measured Phase (Degrees)")
        plt.title(r"$Tone : {0}/11, F_0 = 1 GHz, \Delta F={1:.1e} Hz$".format(tone_index+1,summary_file_model.metadata["tone_spacing"]))
        #plt.savefig(r'Q:\public\Aric\AWG_Phase_Calibration_20180927\11_Tones_10000000000KHz_Spacing\{0}_{1}.png'.format(format(tone_index+1)))
        plt.show()

# %%
plot_all_tones_fix_phase(summary_files[1])

# %%
def plot_all_tones_fix_phase_difference(summary_file_model):
    """Plots the measured phase against the AWG set phase for all tones in the summary file"""
    tones=[]
    mean_differences=[]
    deviation_differences=[]
    for tone_index in range(11):
        tones.append(tone_index)
        start_index=tone_index*(10)
        stop_index=tone_index*(10)+10
        x_data=summary_file_model["AWG_Set_Phase"][start_index:stop_index]
        #corrected_list=360+np.array(summary["Vna_Phase"][8:10])
        vna_data=np.array(fix_phase(summary_file_model["Vna_Phase"][start_index:stop_index]))
        #corrected_scope_list=180+np.array(summary["Scope_Phase"][5:10])
        scope_data=np.array(fix_phase(summary_file_model["Scope_Phase"][start_index:stop_index]))
        plt.plot(x_data,scope_data-vna_data,'bo',
                 label="Difference (Scope-VNA) Mean: {0:3.2f} Std:{1:3.2f}".format(np.mean(scope_data-vna_data),
                                                                                                                np.std(scope_data-vna_data)))
        
        
        mean_differences.append(np.mean(scope_data-vna_data))
        deviation_differences.append(np.std(scope_data-vna_data))
        #plt.plot(x_data,summary_file_model["Vna_Comb_Referenced_Phase"][start_index:stop_index],'gs',label="VNA Comb Reference")
        plt.legend()
        plt.xlabel("AWG Set Phase (Degrees)")
        plt.ylabel("Measured Phase (Degrees)")
        plt.title(r"$Tone : {0}/11, F_0 = 1 GHz, \Delta F={1:.1e} Hz$".format(tone_index+1,
                                                                              summary_file_model.metadata["tone_spacing"]))
        #plt.savefig(r'Q:\public\Aric\AWG_Phase_Calibration_20180927\11_Tones_10000000000KHz_Spacing\{0}_{1}.png'.format(format(tone_index+1)))
        plt.show()
    plt.close()
    plt.errorbar(tones,y=mean_differences,yerr=deviation_differences)
    plt.xlabel("Tone")
    plt.ylabel("Phase Offset")
    plt.show()

# %%
plot_all_tones_fix_phase_difference(summary_files[0])

# %%
summary_file_model=summary_files[1]
tones=[]
mean_differences=[]
deviation_differences=[]
for tone_index in range(11):
    tones.append(tone_index+1)
    start_index=tone_index*(10)
    stop_index=tone_index*(10)+10
    x_data=summary_file_model["AWG_Set_Phase"][start_index:stop_index]
    #corrected_list=360+np.array(summary["Vna_Phase"][8:10])
    vna_data=np.array(fix_phase(summary_file_model["Vna_Phase"][start_index:stop_index]))
    #corrected_scope_list=180+np.array(summary["Scope_Phase"][5:10])
    scope_data=np.array(fix_phase(summary_file_model["Scope_Phase"][start_index:stop_index]))
    plt.plot(x_data,scope_data-vna_data,'bo',
             label="Difference (Scope-VNA) Mean: {0:3.2f} Std:{1:3.2f}".format(np.mean(scope_data-vna_data),
                                                                                                            np.std(scope_data-vna_data)))


    mean_differences.append(np.mean(scope_data-vna_data))
    deviation_differences.append(np.std(scope_data-vna_data))
    #plt.plot(x_data,summary_file_model["Vna_Comb_Referenced_Phase"][start_index:stop_index],'gs',label="VNA Comb Reference")
    plt.legend()
    plt.xlabel("AWG Set Phase (Degrees)")
    plt.ylabel("Measured Phase (Degrees)")
    plt.title(r"$Tone : {0}/11, F_0 = 1 GHz, \Delta F={1:.1e} Hz$".format(tone_index+1,
                                                                          summary_file_model.metadata["tone_spacing"]))
    #plt.savefig(r'Q:\public\Aric\AWG_Phase_Calibration_20180927\11_Tones_10000000000KHz_Spacing\{0}_{1}.png'.format(format(tone_index+1)))
    plt.show()
plt.close()
plt.errorbar(tones,y=mean_differences,yerr=deviation_differences)
plt.xlabel("Tone")
plt.ylabel("Phase Offset")
plt.title(r"Phase Offset, "+"$F_0 = 1 GHz, \Delta F={0:.1e} Hz$".format(summary_file_model.metadata["tone_spacing"]))
plt.show()

# %%
plt.errorbar(x=tones,y=fix_phase(mean_differences),yerr=deviation_differences,fmt="bo")
plt.xlabel("Tone")
plt.ylabel("Phase Offset")
plt.title(r"Phase Offset, "+"$F_0 = 1 GHz, \Delta F={0:.1e} Hz$".format(summary_file_model.metadata["tone_spacing"]))
plt.show()

# %%
path_new_comb_summary=r"X:\AWG_Phase_Calibration_20181001\Comb_Locked_PSG\Schroeder_Phase_10Hz\11_Tones_2500KHz_Spacing\11_Tones_2500000000KHz_Spacing_Summary_20181010_011.txt"
new_comb_schema=read_schema(change_extension(path_new_comb_summary,new_extension="schema"))
new_comb_summary=AsciiDataTable(path_new_comb_summary,**new_comb_schema)

# %%
plot_all_tones_fix_phase(new_comb_summary)

# %%
vna_receiver_path=r"X:\AWG_Phase_Calibration_20181001\Comb_Locked_PSG\Zero_Phase\11_Tones_2500KHz_Spacing\Tone_0_Phase_000_Calibration_Vna_Reciever_Values_20181009_001.txt"

# %%
vna_reciever_schema=read_schema(change_extension(vna_receiver_path,new_extension="schema"))
vna_receiver=AsciiDataTable(vna_receiver_path,**vna_reciever_schema)

# %%
vna_receiver.column_names
# Out:
# ['Frequency',
#  'reA1_Div_A4',
#  'imA1_Div_A4',
#  'reA1',
#  'imA1',
#  'reA4',
#  'imA4',
#  'reA1_Div_B2',
#  'imA1_Div_B2',
#  'reB2',
#  'imB2',
#  'reB3',
#  'imB3']

# %%
plt.plot(abs(np.array(map(lambda x:complex(x[0],x[1]),vna_receiver[["reA4","imA4"]]))))
plt.show()

# %%
data_directory=r"C:\Share\AWG_Phase_Calibration\Schroeder_Phase_10Hz\11_Tones_10000KHz_Spacing"
file_names=os.listdir(data_directory)
analysis_file_names=[]
for file_name in file_names:
    if re.search("txt",file_name,re.IGNORECASE):
        if re.search("rec",file_name,re.IGNORECASE):
            analysis_file_names.append(file_name)
analysis_file_names=map(lambda x:os.path.join(data_directory,x),analysis_file_names)

# %%
analysis_files=map(lambda x: AsciiDataTable(x,**read_schema(change_extension(x,new_extension="schema"))),analysis_file_names)

# %%
from pyMez.Code.Analysis.SParameter import *

# %%
joined_table=analysis_files[0].copy()
for analysis_file in analysis_files[1:]:
    joined_table=joined_table+analysis_file

# %%
mean_table=frequency_model_collapse_multiple_measurements(model=joined_table)

# %%
mean_table.column_names
# Out:
# ['Frequency',
#  'reA1_Div_A4',
#  'imA1_Div_A4',
#  'reA1',
#  'imA1',
#  'reA4',
#  'imA4',
#  'reA1_Div_B2',
#  'imA1_Div_B2',
#  'reB2',
#  'imB2',
#  'reB3',
#  'imB3']

# %%
plt.plot(np.angle(np.array(map(lambda x:complex(x[0],x[1]),mean_table[["reB2","imB2"]])),deg=True))
plt.show()

# %%
plt.plot(np.angle(np.array(map(lambda x:complex(x[0],x[1]),mean_table[["reB3","imB3"]])),deg=True),"bs")
plt.show()

# %%
plt.plot(np.angle(np.array(map(lambda x:complex(x[0],x[1]),mean_table[["reA4","imA4"]])),deg=True),"bs")
plt.show()

# %%
phase_reference_receievers=["A4","B2","B3"]
complex_mean_table=[]
for receiver in phase_reference_receievers:
    complex_array=np.array(map(lambda x:complex(x[0],x[1]),mean_table[["re"+receiver,"im"+receiver]]))
    complex_mean_table.append(complex_mean_table)

# %%
plt.plot(np.angle(complex_mean_table[0],deg=True),"bs")
plt.show()
