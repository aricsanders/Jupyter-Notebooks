# %% [markdown]
# # A comparison of how radical applys its correction
# 1. Open a radical data file (must be saved as matlab v7.3 environment->preferences->General->MAT-files->V7.3)
# 2. plot calibrated data
# 3. retrieve uncorrected DUT
# 4. retrieve solution vector
# 5. plot non reciprocal corrected data
# 6. plot reciprocal corrected data
# 7. compare with 2

# %%
# import libraries
from pyMeasure import *
import os
import h5py
import numpy as np

# %%
# set the directory paths and file path
JUPYTER_DIRECTORY=r'C:\Users\sandersa\PyCharm Projects\Jupyter-Notebooks'
TEST_DIRECTORY=os.path.join(JUPYTER_DIRECTORY,"Radical_Correction_Files")
RADICAL_DATA_PATH=os.path.join(TEST_DIRECTORY,"Example_HD5.mat")

# %%
# open the radical file
radical_data_file=h5py.File(RADICAL_DATA_PATH,'r')

# %%
# Explore the data in the radical data file
print("Level One: {0}".format(radical_data_file.keys()))
print("Level Two: {0}".format(radical_data_file["RadiCalData"].keys()))
def print_hd5_keys(hd5_group):
    """Prints hd5 keys and passes if there are none"""
    try:
        print hd5_group
    except: pass
radical_data_file["RadiCalData"].visit(print_hd5_keys)
# for group in radical_data_file:
#     print group
# Out:
# Level One: [u'#refs#', u'RadiCalData']
# Level Two: [u'C', u'Count', u'Dir', u'Dut', u'DutDir', u'FigureHandle', u'Opts', u'Rdc', u'Ref', u'RefDir', u'Rs2C', u'RsL', u'StatistiCalData', u'Test', u'TestDir']
# C
# Count
# Dir
# Dir/Data
# Dir/RadiCal
# Dir/SpecSheetName
# Dir/SpecSheetPath
# Dir/StatistiCAL
# Dir/SwitchTerms
# Dir/SwitchTerms/Name
# Dir/SwitchTerms/Path
# Dir/SwitchTerms/RFName
# Dir/SwitchTerms/RFPath
# Dut
# Dut/Calibrated
# Dut/CorrectionOption
# Dut/RawStandards
# Dut/RecStds
# Dut/Standards
# Dut/StdsNames
# DutDir
# FigureHandle
# Opts
# Rdc
# Ref
# Ref/Calibrated
# Ref/Guess
# Ref/Guess/CIR
# Ref/Guess/EpsEff
# Ref/Guess/Error
# Ref/Guess/PropConst
# Ref/Guess/RsModel
# Ref/Guess/S1
# Ref/Guess/S1Zc
# Ref/Guess/S2
# Ref/Guess/S2Zc
# Ref/Guess/T1
# Ref/Guess/T2
# Ref/Guess/Z
# Ref/Lengths
# Ref/MapFunc
# Ref/Name
# Ref/RFSwitchTerms
# Ref/RawStandards
# Ref/RecStds
# Ref/SeriesR
# Ref/SpecSheet
# Ref/Standards
# Ref/StdsNames
# Ref/SwitchTerms
# Ref/TRL
# Ref/TRL/C
# Ref/TRL/Eps
# Ref/TRL/ErrEps
# Ref/TRL/Models
# Ref/TRL/Models/Rs
# Ref/TRL/Models/RsCir
# Ref/TRL/Models/RsErr
# Ref/TRL/Models/RsModel
# Ref/TRL/Models/S1
# Ref/TRL/Models/S1Cir
# Ref/TRL/Models/S1Err
# Ref/TRL/Models/S1Model
# Ref/TRL/PropConst
# Ref/TRL/T1
# Ref/TRL/T1Zc
# Ref/TRL/T1Zct2
# Ref/TRL/T1t2
# Ref/TRL/T2
# Ref/TRL/T2Zc
# Ref/TRL/T2Zct2
# Ref/TRL/T2t2
# Ref/TRL/W
# Ref/TRL/Z
# RefDir
# Rs2C
# RsL
# StatistiCalData
# StatistiCalData/C
# StatistiCalData/Cerr
# StatistiCalData/Dir
# StatistiCalData/Dir/Data
# StatistiCalData/Dir/RadiCal
# StatistiCalData/Dir/SpecSheetName
# StatistiCalData/Dir/SpecSheetPath
# StatistiCalData/Dir/StatistiCAL
# StatistiCalData/Dir/SwitchTerms
# StatistiCalData/Dir/SwitchTerms/Name
# StatistiCalData/Dir/SwitchTerms/Path
# StatistiCalData/Dir/SwitchTerms/RFName
# StatistiCalData/Dir/SwitchTerms/RFPath
# StatistiCalData/Eps
# StatistiCalData/ErrEps
# StatistiCalData/F
# StatistiCalData/Ignore
# StatistiCalData/Lengths
# StatistiCalData/Menu
# StatistiCalData/Menu/InitData
# StatistiCalData/Menu/Name
# StatistiCalData/Menu/Path
# StatistiCalData/MenuPath
# StatistiCalData/P
# StatistiCalData/Primer
# StatistiCalData/RecStds
# StatistiCalData/RefDir
# StatistiCalData/Rs
# StatistiCalData/S
# StatistiCalData/S1
# StatistiCalData/S2
# StatistiCalData/Solution
# StatistiCalData/Std
# StatistiCalData/StdsNames
# StatistiCalData/T1
# StatistiCalData/T2
# StatistiCalData/Uncertainty
# StatistiCalData/W
# Test
# TestDir

# %%
# The corrected S parameters for short
corrected_short=np.array(radical_data_file["RadiCalData/StatistiCalData/S"])

# %%
# The Frequency list
frequency_list=np.array(radical_data_file["RadiCalData/StatistiCalData/F"])[0].tolist()

# %%
# putting them into [f,S11,S21,S12,S22] format
sparameters=[]
sparameters_flipped=[]
for index,item in enumerate(frequency):
    [S11,S21,S12,S22]=[complex(corrected_s[0][index][0],corrected_s[0][index][1]),
                       complex(corrected_s[1][index][0],corrected_s[1][index][1]),
                       complex(corrected_s[2][index][0],corrected_s[2][index][1]),
                       complex(corrected_s[3][index][0],corrected_s[3][index][1])]
    new_row=[item,S11,S21,S12,S22]
    sparameters.append(new_row)
    sparameters_flipped.append([item,S11,S12,S21,S22])

# %%
# make a s2p file out of them
new_s2p=S2PV1(None,sparameter_complex=sparameters)
new_s2p_flipped=S2PV1(None,sparameter_complex=sparameters_flipped)

# %%
# %matplotlib notebook
# Now show them
new_s2p.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
compare_s2p_plots([new_s2p],labels=["Corrected Short"],format="db")
# Out:
# <img src="data:image/png;base64,...">

# %%
compare_s2p_plots([new_s2p,new_s2p_flipped],labels=["Corrected Short","Transmission Flipped"],format="MA")
# Out:
# <img src="data:image/png;base64,...">

# %%
np.array(radical_data_file["RadiCalData/Dut/Calibrated"][0])
# Out:
# array([<HDF5 object reference>, <HDF5 object reference>], dtype=object)
