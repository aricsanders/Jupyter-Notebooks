# %% [markdown]
# # Multidimensional Calibration Comparison
#
# Goal: To compare two calibrations (corrections) at different points in impedance space
#
# Method:
# 1. Create a set of "synthetic" ~~standards~~ DUTs in the DUT reference plane (rename to DUTs). These standards should have the following properties:
#         + Occupy many points in impedance space
#         + Be constant as a function of frequency
#         + Be spaced further apart than the mean error
# 2. Use the reference (calibration with lowest uncertainty) to move the points to the measurement plane. This can be thought of uncorrecting the data
# 3. Use the comparison calibration to move the points from the measurement plane to the reference plane
# 4. Color code the points based on their distance from the original points

# %%
from pyMeasure import *
# Out:
# Importing pyMeasure, this should take roughly 30 seconds

# %%
# first choose the points
r1=.98
r2=.2
r3=.6
def create_synthetic_standards_DUT_plane(frequency_list,r1,r2,r3,**options):
    """Creates a set of points in the DUT reference plane, outputs a list of S2PV1 objects"""
    defaults={}
    standard_options={}
    for key,value in defaults.iteritems():
        standard_options[key]=value
    for key,value in options.iteritems():
        standard_options[key]=value
    output_list=[]
    s11_points=[]
    s21_points=[]
    for i in range(8):
        s11_points.append(cmath.rect(r1,cmath.pi*(i)/4))
    for i in range(4):
        s11_points.append(cmath.rect(r2,cmath.pi*(i)/2+cmath.pi/4))
    for i in range(8):
        s11_points.append(cmath.rect(r3,cmath.pi*(i)/4+cmath.pi/8))
    for i in range(8):
        s21_points.append(cmath.rect(np.sqrt(1-r1**2),cmath.pi*(i)/4))
    for i in range(4):
        s21_points.append(cmath.rect(np.sqrt(1-r2**2),cmath.pi*(i)/2+cmath.pi/4))
    for i in range(8):
        s21_points.append(cmath.rect(np.sqrt(1-r3**2),cmath.pi*(i)/4+cmath.pi/8))
    for index,point in enumerate(s11_points):
        data_list=[]
        for f in frequency_list:
            data_list.append([f,point,s21_points[index],s21_points[index],point])
        output_list.append(S2PV1(sparameter_complex=data_list,option_line='# GHz S RI R 50'))
    return output_list
            
def create_synthetic_standards_measurement_plane(r1,r2,r3,s4p,**options):
    """Creates a set of points in the DUT reference plane, outputs a list of S2PV1 objects"""
    defaults={}
    standard_options={}
    for key,value in defaults.iteritems():
        standard_options[key]=value
    for key,value in options.iteritems():
        standard_options[key]=value
    frequency_list=s4p["Frequency"]
    output_list=[]
    s11_points=[]
    s21_points=[]
    for i in range(8):
        s11_points.append(cmath.rect(r1,cmath.pi*(i)/4))
    for i in range(4):
        s11_points.append(cmath.rect(r2,cmath.pi*(i)/2+cmath.pi/4))
    for i in range(8):
        s11_points.append(cmath.rect(r3,cmath.pi*(i)/4+cmath.pi/8))
    for i in range(8):
        s21_points.append(cmath.rect(np.sqrt(1-r1**2),cmath.pi*(i)/4))
    for i in range(4):
        s21_points.append(cmath.rect(np.sqrt(1-r2**2),cmath.pi*(i)/2+cmath.pi/4))
    for i in range(8):
        s21_points.append(cmath.rect(np.sqrt(1-r3**2),cmath.pi*(i)/4+cmath.pi/8))
    for index,point in enumerate(s11_points):
        data_list=[]
        for f in frequency_list:
            data_list.append([f,point,s21_points[index],s21_points[index],point])
        measurement_data_list=uncorrect_sparameters_sixteen_term(sparameters_complex=data_list,
                                           sixteen_term_correction=s4p.sparameter_complex)
        output_list.append(S2PV1(sparameter_complex=measurement_data_list,option_line='# GHz S RI R 50'))
    return output_list

# %%
def correct_all_sixteen_term(s2p_list,correction):
    """Corrects all s2ps in list and returns a new list of corrected DUTs"""
    output_list=[]
    for s2p in s2p_list:
        corrected_s2p=correct_sparameters_sixteen_term(sparameters_complex=s2p.sparameter_complex,
                                                       sixteen_term_correction=correction.sparameter_complex)
        output_list.append(S2PV1(sparameter_complex=corrected_s2p))
    return output_list

# %%
reference_correction=SNP(r"C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\Solution_0.s4p")
measurement_plane_s2ps=create_synthetic_standards_measurement_plane(r1,r2,r3,reference_correction)
plt.rcParams.update({'font.size': 16})
map(lambda x: x.change_data_format("RI"),measurement_plane_s2ps)
s2ps=measurement_plane_s2ps
fig,axes=plt.subplots(nrows=2, ncols=2, figsize=(7,7),dpi=80)
plot_names=["S11","S21","S12","S22"]
for s2p in s2ps:
    for index,ax in enumerate(axes.flat):
        ax.plot(s2p["re{0}".format(plot_names[index])],
                s2p["im{0}".format(plot_names[index])],'x');
        ax.set_ylim([-1.2,1.2]);
        ax.set_xlim([-1.2,1.2]);
        ax.set_title(plot_names[index]);
        ax.set_xlabel("Re({0})".format(plot_names[index]))
        ax.set_ylabel("Imag({0})".format(plot_names[index]))
plt.tight_layout()
plt.show()

# %%
def two_port_complex_plot(s2p_list,**options):
    fig,axes=plt.subplots(nrows=2, ncols=2, figsize=(7,7),dpi=80)
    plot_names=["S11","S21","S12","S22"]
    for s2p in s2p_list:
        for index,ax in enumerate(axes.flat):
            ax.plot(s2p["re{0}".format(plot_names[index])],
                    s2p["im{0}".format(plot_names[index])],'o',fillstyle='none',markersize=10);
            ax.set_ylim([-1.2,1.2]);
            ax.set_xlim([-1.2,1.2]);
            ax.set_title(plot_names[index]);
            ax.set_xlabel("Re({0})".format(plot_names[index]))
            ax.set_ylabel("Imag({0})".format(plot_names[index]))
    plt.tight_layout()
    plt.show()

# %%
comparison_correction=SNP(r"C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160825\Solution_0.s4p")
comparison_correction_2=SNP(r"C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\Solution_0.s4p")

# %%
comparison_correction_list=[]
dates=["20160822","20160824","20160825",
      "20160826","20160914","20160915",
      "20160916","20160919","20160920",
      "20160921","20160923","20160926"]
for date in dates:
    correction=SNP(r"C:\Share\VNA_OSLT_TypeN_Room1207_2016\{0}\Solution_0.s4p".format(date))
    comparison_correction_list.append(correction)

# %%
def two_port_complex_plot_compare(s2p_list_1,s2p_list_2,title=None,**options):
    map(lambda x: x.change_data_format("RI"),s2p_list_1)
    map(lambda x: x.change_data_format("RI"),s2p_list_2)


    fig,axes=plt.subplots(nrows=2, ncols=2, figsize=(7,7),dpi=80)
    plot_names=["S11","S21","S12","S22"]

    for s2p in s2p_list_2:
        for index,ax in enumerate(axes.flat):
            ax.plot(s2p["re{0}".format(plot_names[index])],
                    s2p["im{0}".format(plot_names[index])],'bx');
            ax.set_ylim([-1.1,1.1]);
            ax.set_xlim([-1.1,1.1]);
            ax.set_title(plot_names[index]);
            #ax.set_xlabel("Re({0})".format(plot_names[index]))
            #ax.set_ylabel("Imag({0})".format(plot_names[index]))
    for s2p in s2p_list_1:
        for index,ax in enumerate(axes.flat):
            ax.plot(s2p["re{0}".format(plot_names[index])],
                    s2p["im{0}".format(plot_names[index])],'yo',fillstyle='none',markersize=10);
            ax.set_ylim([-1.1,1.1]);
            ax.set_xlim([-1.1,1.1]);
            ax.set_title(plot_names[index]);
    fig.suptitle(title)
    plt.tight_layout()
    plt.show()

# %%
def compare_calibrations_script(c1,c2,title=None):
    """"""
    r1=.98
    r2=.2
    r3=.6
    s2p_list=create_synthetic_standards_DUT_plane(c1["Frequency"],r1,r2,r3)
    measurement_plane_s2ps=create_synthetic_standards_measurement_plane(r1,r2,r3,c1)
    comparison_s2ps_dut_plane=correct_all_sixteen_term(measurement_plane_s2ps,c2)
    two_port_complex_plot_compare(s2p_list,comparison_s2ps_dut_plane,title=title)

# %%
for index,date in enumerate(dates[:]):
    compare_calibrations_script(reference_correction,comparison_correction_list[index],title=date)

# %%
comparison_s2ps_dut_plane=correct_all_sixteen_term(measurement_plane_s2ps,comparison_correction)
comparison_s2ps_dut_plane_2=correct_all_sixteen_term(measurement_plane_s2ps,comparison_correction_2)

# %%
dut_plane_s2ps=create_synthetic_standards_DUT_plane(reference_correction["Frequency"],r1,r2,r3)
compare_s2p_plots([comparison_s2ps_dut_plane[2],dut_plane_s2ps[2]],display_legend=False,format="RI");

# %%
two_port_complex_plot_compare(dut_plane_s2ps,comparison_s2ps_dut_plane_2)

# %%
two_port_complex_plot_compare(dut_plane_s2ps,comparison_s2ps_dut_plane)

# %%
def compare_calibrations_script(c1_path,c2_path):
    """"""
    c1=SNP(c1_path,number_ports=4)
    c2=SNP(c2_path,number_ports=4)
    r1=.98
    r2=.2
    r3=.6
    s2p_list=create_synthetic_standards_DUT_plane(c1["Frequency"],r1,r2,r3)
    measurement_plane_s2ps=create_synthetic_standards_measurement_plane(r1,r2,r3,c1)
    comparison_s2ps_dut_plane=correct_all_sixteen_term(measurement_plane_s2ps,c2)
    two_port_complex_plot_compare(s2p_list,comparison_s2ps_dut_plane)

# %%
c1_path=r"C:\Users\sandersa\Desktop\Chris Rs vs TRL\Solution_To50ohm_AtRefHalfThru_0.s4p"
c2_path=r"C:\Users\sandersa\Desktop\Chris Rs vs TRL\Solution_0.s4p"
compare_calibrations_script(c1_path,c2_path)

# %%
# %matplotlib wx
import matplotlib.animation as animation
fig2 = plt.figure()

x = np.arange(-9, 10)
y = np.arange(-9, 10).reshape(-1, 1)
base = np.hypot(x, y)
ims = []
for add in np.arange(15):
    ims.append((plt.pcolor(x, y, base + add, norm=plt.Normalize(0, 30)),))

im_ani = animation.ArtistAnimation(fig2, ims, interval=50, repeat_delay=3000,
                                   blit=True)
# To save this second animation with some metadata, use the following command:
# im_ani.save('im.mp4', metadata={'artist':'Guido'})

plt.show()

# %%
def two_port_complex_plot_compare_animate(s2p_list_1,s2p_list_2,**options):
    map(lambda x: x.change_data_format("RI"),s2p_list_1)
    map(lambda x: x.change_data_format("RI"),s2p_list_2)


    fig,axes=plt.subplots(nrows=2, ncols=2, figsize=(7,7),dpi=80)
    plot_names=["S11","S21","S12","S22"]
    images=[]
    frequency_list=s2p_list_2[0]["Frequency"]
    for f_index,f in enumerate(frequency_list):
    
        for s2p in s2p_list_2:
            for index,ax in enumerate(axes.flat):
                ax.plot(s2p["re{0}".format(plot_names[index])][f_index],
                        s2p["im{0}".format(plot_names[index])][f_index],'bx');
                ax.set_ylim([-1.1,1.1]);
                ax.set_xlim([-1.1,1.1]);
                ax.set_title(plot_names[index]); 
        for s2p in s2p_list_1:
            for index,ax in enumerate(axes.flat):
                ax.plot(s2p["re{0}".format(plot_names[index])][f_index],
                        s2p["im{0}".format(plot_names[index])][f_index],'yo',fillstyle='none',markersize=10);
                ax.set_ylim([-1.1,1.1]);
                ax.set_xlim([-1.1,1.1]);
                ax.set_title(plot_names[index]);
        fig.suptitle("f = {0}".format(f))
        
        plt.tight_layout()
        plt.savefig("C:\Share\Calibration_Comparison\TRLvsSeriesR4\Calibration_Compare_f_{0}.png".format(f))

# %%
fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):T
    line.set_ydata(np.sin(x + i/10.0))  # update the data
    return line,


# Init only required for blitting to give a clean slate.
def init():
    line.set_ydata(np.ma.array(x, mask=True))
    return line,

ani = animation.FuncAnimation(fig, animate, np.arange(1, 200), init_func=init,
                              interval=25, blit=True)
plt.show()

# %%
def compare_calibrations_script(c1_path,c2_path):
    """"""
    c1=SNP(c1_path,number_ports=4)
    c2=SNP(c2_path,number_ports=4)
    r1=.98
    r2=.2
    r3=.6
    s2p_list=create_synthetic_standards_DUT_plane(c1["Frequency"],r1,r2,r3)
    measurement_plane_s2ps=create_synthetic_standards_measurement_plane(r1,r2,r3,c1)
    comparison_s2ps_dut_plane=correct_all_sixteen_term(measurement_plane_s2ps,c2)
    two_port_complex_plot_compare_animate(s2p_list,comparison_s2ps_dut_plane)

# %%
c1_path=r"C:\Share\8510calfiles\24Cal\MUF Result Files\Solutions\Solution_0.s4p"
c2_path=r"C:\Share\8510calfiles\24Cal\SOLT\MUF Results\Solutions\Solution_0.s4p"
compare_calibrations_script(c1_path,c2_path)

# %%
c1_path=r"C:\Users\sandersa\Desktop\Chris Rs vs TRL\Solution_To50ohm_AtRefHalfThru_0.s4p"
c2_path=r"C:\Users\sandersa\Desktop\Chris Rs vs TRL\Solution_0.s4p"
compare_calibrations_script(c1_path,c2_path)

# %%
measurement_file=MUFMeasurement(r"C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\Solution.meas")

# %%
covariance_dictionary=measurement_file.get_covariance_dictionary()

# %%
parameter_dictionary=measurement_file.get_name_parameter_dictionary()

# %%
covaraiance_comparison_correction_list=[]
for item in covariance_dictionary:
    correction=SNP(r"C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\Solutions\{0}.s4p".format(item["name"]))
    covaraiance_comparison_correction_list.append(correction)

# %%
for index,covariance in enumerate(covariance_dictionary[:]):
    compare_calibrations_script(reference_correction,covaraiance_comparison_correction_list[index],
                                title=parameter_dictionary[covariance["name"]])

# %%
standards=["short","open","fixload","thru","gthru"]
cals=["cal1","cal2"]
dates=["20160822","20160824","20160825",
      "20160826","20160914","20160915",
      "20160916","20160919","20160920",
      "20160921","20160923","20160926"]
standard_measurements=[]
std_list=[]
for date in dates:
    date_list=[]
    try:
        for cal in cals:
            standard_dictionary={}
            for standard in standards:
                path=r"C:\Share\VNA_OSLT_TypeN_Room1207_2016\{0}\{1}\{2}.s2p".format(date,cal,standard)
                directory=r"C:\Share\VNA_OSLT_TypeN_Room1207_2016\{0}\{1}".format(date,cal,standard)
                print("{0} is {1}".format("path",path))
                if os.path.split(path)[-1] in os.listdir(directory):

                    standard_dictionary[standard]=S2PV1(path)
                else: 
                    standard2=standard+"2"
                    path=r"C:\Share\VNA_OSLT_TypeN_Room1207_2016\{0}\{1}\{2}.s2p".format(date,cal,standard2)
                    print("{0} is {1}".format("path",path))

                    if os.path.split(path)[-1] in os.listdir(directory):
                        standard_dictionary[standard]=S2PV1(path)

            date_list.append(standard_dictionary)
        standard_measurements.append(date_list)
    except:raise
#         print("Passing Date {0} because of error".format(date))
#         new_dates=dates.remove(date)
# Out:
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\cal1\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\cal1\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\cal1\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\cal1\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\cal1\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\cal2\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\cal2\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\cal2\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\cal2\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160822\cal2\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160824\cal1\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160824\cal1\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160824\cal1\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160824\cal1\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160824\cal1\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160824\cal2\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160824\cal2\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160824\cal2\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160824\cal2\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160824\cal2\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160825\cal1\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160825\cal1\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160825\cal1\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160825\cal1\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160825\cal1\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160825\cal2\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160825\cal2\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160825\cal2\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160825\cal2\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160825\cal2\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal1\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal1\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal1\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal1\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal1\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal2\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal2\short2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal2\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal2\open2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal2\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal2\fixload2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal2\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal2\thru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal2\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160826\cal2\gthru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal1\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal1\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal1\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal1\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal1\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal2\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal2\short2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal2\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal2\open2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal2\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal2\fixload2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal2\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal2\thru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal2\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160914\cal2\gthru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal1\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal1\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal1\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal1\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal1\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal2\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal2\short2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal2\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal2\open2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal2\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal2\fixload2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal2\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal2\thru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal2\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160915\cal2\gthru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal1\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal1\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal1\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal1\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal1\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal2\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal2\short2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal2\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal2\open2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal2\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal2\fixload2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal2\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal2\thru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal2\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160916\cal2\gthru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal1\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal1\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal1\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal1\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal1\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal2\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal2\short2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal2\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal2\open2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal2\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal2\fixload2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal2\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal2\thru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal2\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160919\cal2\gthru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal1\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal1\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal1\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal1\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal1\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal2\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal2\short2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal2\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal2\open2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal2\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal2\fixload2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal2\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal2\thru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal2\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160920\cal2\gthru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal1\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal1\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal1\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal1\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal1\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal2\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal2\short2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal2\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal2\open2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal2\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal2\fixload2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal2\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal2\thru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal2\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160921\cal2\gthru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal1\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal1\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal1\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal1\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal1\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal2\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal2\short2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal2\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal2\open2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal2\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal2\fixload2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal2\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal2\thru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal2\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160923\cal2\gthru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal1\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal1\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal1\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal1\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal1\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal2\short.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal2\short2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal2\open.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal2\open2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal2\fixload.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal2\fixload2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal2\thru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal2\thru2.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal2\gthru.s2p
# path is C:\Share\VNA_OSLT_TypeN_Room1207_2016\20160926\cal2\gthru2.s2p

# %%
standard_measurements
# Out:
# [[{'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000119FAF288>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000169EC6388>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000013471A3C8>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000016D087B48>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000014C576308>},
#   {'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000069B0C508>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000110036608>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000016B908448>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001696AF3C8>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000011461B548>}],
#  [{'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000000E2CF3788>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000011C2BB8C8>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000115AD6748>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000120A9E6C8>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000012217C848>},
#   {'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000133E01A48>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000013A55FB48>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000132A289C8>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000011BCD3948>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000013395CAC8>}],
#  [{'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001423B3D08>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000143601E08>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000013B5FAC88>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000013BD15C08>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000143B5FD48>},
#   {'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000014B248F88>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000016CF28748>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000014B711EC8>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000014A38AE88>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000152012FC8>}],
#  [{'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000172BA6B88>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000151461C88>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000180E7DAC8>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000016DFA1A08>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000018096CC08>},
#   {'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000015927EE08>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000015C86BF08>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001549F5D88>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000153EAFD08>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000015BD77E88>}],
#  [{'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000016430F148>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000011BD7C208>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000163888048>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000016247EFC8>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000183BCF188>},
#   {'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000000AC8793C8>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001634854C8>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000011BB1E348>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001036B42C8>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000139AF3448>}],
#  [{'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001830C1688>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000013BABB788>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000015C3275C8>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001856E1588>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001107DD6C8>},
#   {'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000018151B908>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001787D3A08>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000011CCFC888>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001845D8808>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000177EF2988>}],
#  [{'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000178E6CB88>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000017812EC88>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000119C94B08>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000015110DA88>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000179279C48>},
#   {'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000153726E48>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000182372F48>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000142BDEDC8>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000139306D48>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000168D92EC8>}],
#  [{'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000173451148>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000175301208>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001717AC088>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000017663B048>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001844F91C8>},
#   {'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000179EDA3C8>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000017EFF74C8>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001699DF348>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000018026B2C8>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000182298448>}],
#  [{'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000017F609688>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000017E7C7788>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000180CC05C8>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000182E7A588>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000017B4E56C8>},
#   {'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001860E67C8>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000187A86988>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000017D4AF888>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000017FD14808>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000186DD48C8>}],
#  [{'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000018A06DB88>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000018BA4CC88>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001893A6B08>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001886DFA88>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000018AD5AC08>},
#   {'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000018DFF4E08>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000018F9D2F08>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000018D32CD88>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000018C664D08>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000018ECA1E88>}],
#  [{'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000191FA00C8>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000193A45208>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001912B4048>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001905ABF48>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000192CCC188>},
#   {'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x00000001960E9388>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000197C08488>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000195382308>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000019468A288>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000196DF3408>}],
#  [{'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000019A2F4648>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000019BD10708>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000199596588>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x0000000198850548>,
#    'thru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000019AF796C8>},
#   {'fixload': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000019E4008C8>,
#    'gthru': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000019F0FA948>,
#    'open': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000019D6BC848>,
#    'short': <Code.DataHandlers.TouchstoneModels.S2PV1 instance at 0x000000019C9377C8>}]]

# %%
shorts=[measurement[1]["short"] for measurement in standard_measurements[:]]
opens=[measurement[1]["open"] for measurement in standard_measurements[:]]
loads=[measurement[1]["fixload"] for measurement in standard_measurements[:]]
thrus=[measurement[1]["thru"] for measurement in standard_measurements[0:-1]]
gthrus=[measurement[1]["gthru"] for measurement in standard_measurements[:]]

# %%
plt.rcParams.update({'font.size': 12})

names=["shorts","opens","loads","thrus","gthrus"]
cal_data_list=[shorts,opens,loads,thrus,gthrus]
for index,data in enumerate(cal_data_list):
    compare_s2p_plots(data,plot_title=names[index],display_legend=False,format="RI")

# %%
cal=1
thrus=[]
for measurement in standard_measurements[:]:
    sorted_keys=sorted(measurement[cal].keys())
    thru_key=sorted_keys[-1]
    print(thru_key)
    thrus.append(measurement[cal][thru_key])
# Out:
# thru
# thru
# thru
# thru
# thru
# thru
# thru
# thru
# thru
# thru
# thru
# short

# %%
compare_s2p_plots(shorts,labels=dates,display_legend=False);

# %%
compare_s2p_plots(opens[3:5],labels=dates[3:5],display_legend=True);

# %%
compare_s2p_plots(thrus[0:-2],labels=dates,display_legend=False);

# %%
compare_s2p_plots(loads,labels=dates,display_legend=True);

# %%
compare_s2p_plots(gthrus,labels=dates,display_legend=False);
