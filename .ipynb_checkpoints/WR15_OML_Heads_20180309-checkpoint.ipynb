# %%
from pyMez import *
# Out:
# Importing pyMez, this should take roughly 30 seconds
# Importing Code.DataHandlers.GeneralModels
# It took 0.311 s to import Code.DataHandlers.GeneralModels
# Importing Code.DataHandlers.HTMLModels
# It took 0.069 s to import Code.DataHandlers.HTMLModels
# Importing Code.DataHandlers.NISTModels
# It took 0.968 s to import Code.DataHandlers.NISTModels
# Importing Code.DataHandlers.TouchstoneModels
# It took 0.005 s to import Code.DataHandlers.TouchstoneModels
# Importing Code.DataHandlers.XMLModels
# It took 0.06 s to import Code.DataHandlers.XMLModels
# Importing Code.DataHandlers.ZipModels
# It took 0.004 s to import Code.DataHandlers.ZipModels
# Importing Code.InstrumentControl.Experiments
# It took 0.321 s to import Code.InstrumentControl.Experiments
# Importing Code.InstrumentControl.Instruments
# It took 0.008 s to import Code.InstrumentControl.Instruments
# Importing Code.Utils.Names
# It took 0.007 s to import Code.Utils.Names
# It took 1.753 s to import all of the active modules

# %%
zva=VNA("GPIB::20")

# %%
frequency_start=50*10**9
frequency_stop=75*10**9
number_points=251
#data_directory=r"C:\Share\WR15_20180213"
data_directory=r"C:\Share\WR15_Kits_VDI_20180223"

# %%
#test_frequency_list=np.linspace(frequency_start,frequency_stop,number_points)
# Note with the frequency converter you can't initialize the sweeps. Set up the zva traces manually
# to have "S11","S21","S12","S22","A1_D1","B1_D1","A2_D1","B2_D1"

# %%
specific_description="True_Thru"
zva.set_IFBW(10)
zva.set_frequency(frequency_start,frequency_stop,number_points)
s2p=zva.measure_sparameters()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15",extension="s2p")
s2p.path=os.path.join(data_directory,name)
s2p.save()
s2p.show();
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
w2p=zva.measure_w2p()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15_Wave_Parameters",extension="w2p")
w2p.path=os.path.join(data_directory,name)
w2p.save()
w2p.options["IFBW"]=zva.get_IFBW()
w2p.options["Power"]=zva.get_power()
w2p.options["Extender"]="VNAX530"
w2p.options["Measurement_Timestamp"]=datetime.datetime.utcnow()
w2p.save_schema(change_extension(os.path.join(data_directory,name),new_extension="schema"))

# %%
specific_description="Match_10015_P1_FixedLoad_70020_P2"
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
s2p=zva.measure_sparameters()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15",extension="s2p")
s2p.path=os.path.join(data_directory,name)
s2p.save()
s2p.show();
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
w2p=zva.measure_w2p()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15_Wave_Parameters",extension="w2p")
w2p.path=os.path.join(data_directory,name)
w2p.save()
w2p.options["IFBW"]=zva.get_IFBW()
w2p.options["Power"]=zva.get_power()
w2p.options["Extender"]="VNAX530"
w2p.save_schema(change_extension(os.path.join(data_directory,name),new_extension="schema"))

# %%
specific_description="Short_10072_P1_Keysight_Short_P2"
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
s2p=zva.measure_sparameters()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15",extension="s2p")
s2p.path=os.path.join(data_directory,name)
s2p.save()
s2p.show();
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
w2p=zva.measure_w2p()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15_Wave_Parameters",extension="w2p")
w2p.path=os.path.join(data_directory,name)
w2p.save()
w2p.options["IFBW"]=zva.get_IFBW()
w2p.options["Power"]=zva.get_power()
w2p.options["Extender"]="VNAX530"
w2p.options["Measurement_Timestamp"]=datetime.datetime.utcnow()
w2p.save_schema(change_extension(os.path.join(data_directory,name),new_extension="schema"))

# %%
specific_description="Short_10072_Shim_100018_P1_Keysight_Short_Shim_P2"
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
s2p=zva.measure_sparameters()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15",extension="s2p")
s2p.path=os.path.join(data_directory,name)
s2p.save()
s2p.show();
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
w2p=zva.measure_w2p()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15_Wave_Parameters",extension="w2p")
w2p.path=os.path.join(data_directory,name)
w2p.save()
w2p.options["IFBW"]=zva.get_IFBW()
w2p.options["Power"]=zva.get_power()
w2p.options["Extender"]="VNAX530"
w2p.options["Measurement_Timestamp"]=datetime.datetime.utcnow()
w2p.save_schema(change_extension(os.path.join(data_directory,name),new_extension="schema"))

# %% [markdown]
# shim_thickness=.064"
# shim_thickness~
# Multical bottom cutoff frequency

# %%
.064*25.4
# Out:
# 1.6256

# %%
specific_description="WR15_Kit_Short_P1"
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
s2p=zva.measure_sparameters()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15",extension="s2p")
s2p.path=os.path.join(data_directory,name)
s2p.save()
s2p.show();
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
w2p=zva.measure_w2p()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15_Wave_Parameters",extension="w2p")
w2p.path=os.path.join(data_directory,name)
w2p.save()
w2p.options["IFBW"]=zva.get_IFBW()
w2p.options["Power"]=zva.get_power()
w2p.options["Extender"]="VNAX530"
w2p.options["Measurement_Timestamp"]=datetime.datetime.utcnow()
w2p.options["Connector_Type_Measurement"]="WR15"
w2p.save_schema(change_extension(os.path.join(data_directory,name),new_extension="schema"))

# %%
specific_description="WR15_Kit_Short_P2"
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
s2p=zva.measure_sparameters()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15",extension="s2p")
s2p.path=os.path.join(data_directory,name)
s2p.save()
s2p.show();
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
w2p=zva.measure_w2p()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15_Wave_Parameters",extension="w2p")
w2p.path=os.path.join(data_directory,name)
w2p.save()
w2p.options["IFBW"]=zva.get_IFBW()
w2p.options["Power"]=zva.get_power()
w2p.options["Extender"]="VNAX530"
w2p.options["Measurement_Timestamp"]=datetime.datetime.utcnow()
w2p.options["Connector_Type_Measurement"]="WR15"
w2p.save_schema(change_extension(os.path.join(data_directory,name),new_extension="schema"))

# %%
specific_description="WR15_Line_5079"
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
s2p=zva.measure_sparameters()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15",extension="s2p")
s2p.path=os.path.join(data_directory,name)
s2p.save()
s2p.show();
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
w2p=zva.measure_w2p()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15_Wave_Parameters",extension="w2p")
w2p.path=os.path.join(data_directory,name)
w2p.save()
w2p.options["IFBW"]=zva.get_IFBW()
w2p.options["Power"]=zva.get_power()
w2p.options["Extender"]="VNAX530"
w2p.options["Measurement_Timestamp"]=datetime.datetime.utcnow()
w2p.options["Connector_Type_Measurement"]="WR15"
w2p.save_schema(change_extension(os.path.join(data_directory,name),new_extension="schema"))

# %%
specific_description="WR15_Line_4909"
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
s2p=zva.measure_sparameters()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15",extension="s2p")
s2p.path=os.path.join(data_directory,name)
s2p.save()
s2p.show();
#zva.set_IFBW(10)
#zva.set_frequency(frequency_start,frequency_stop,number_points)
w2p=zva.measure_w2p()
name=auto_name(directory=data_directory,specific_descriptor=specific_description,
               general_descriptor="WR15_Wave_Parameters",extension="w2p")
w2p.path=os.path.join(data_directory,name)
w2p.save()
w2p.options["IFBW"]=zva.get_IFBW()
w2p.options["Power"]=zva.get_power()
w2p.options["Extender"]="VNAX530"
w2p.options["Measurement_Timestamp"]=datetime.datetime.utcnow()
w2p.options["Connector_Type_Measurement"]="WR15"
w2p.save_schema(change_extension(os.path.join(data_directory,name),new_extension="schema"))
