# %%
from pyMez.Code.DataHandlers.GraphModels import *
from ipywidgets import *

# %%
test_graph=DataTableGraph()

# %%
test_graph.show()

# %%
# %matplotlib inline
history=[]
def move_and_show(end_node_number):
    node=test_graph.node_names[end_node_number]
    test_graph.move_to_node(node)
    print("*"*80)
    print("{0}".format(test_graph.node_descriptions[end_node_number])+" {0}".format(test_graph.state))
    print("*"*80)
    test_graph.show(descriptions=True)
    print test_graph.data
    history.append(node)
    
interact(move_and_show,end_node_number=(0,len(test_graph.node_names)-1,1))
# Out:
# ********************************************************************************
# Excel Workbook [0, 0, 1, 0, 0, 0]
# ********************************************************************************
# Test.xlsx
# <function __main__.move_and_show>
