# %%
from pyMeasure import *
# Out:
# Importing pyMeasure, this should take roughly 30 seconds
# The module smithplot was not found,please put it on the python path
# The module smithplot was not found,please put it on the python path

# %%
calrep=TwoPortCalrepModel(os.path.join(TESTS_DIRECTORY,"922729.asc"))

# %%
xml=AsciiDataTable_to_XmlDataTable(calrep.joined_table)

# %%
xml.save()

# %%
results_file=ResultFileModel(r"C:\Share\resfiles\CTN210")

# %%
plot_frequency_model(results_file)

# %%
results_file.remove_column("Number_Measurements")

# %%
print results_file
# Out:
# Frequency,magS11,argS11,magS21,argS21,magS22,argS22
# 2.0  0.02991  38.318  0.498686946055  -147.918  0.00822  -74.572
# 3.0  0.03593  5.48  0.497792099955  138.159  0.00625  -108.604
# 4.0  0.03591  -25.975  0.497116868319  64.145  0.01348  -149.375
# 5.0  0.03061  -58.502  0.496624910733  -10.01  0.02533  132.079
# 6.0  0.01651  -103.647  0.496386543803  -84.368  0.03108  48.644
# 7.0  0.01135  85.905  0.496248834752  -158.997  0.02523  -38.803
# 8.0  0.04049  22.302  0.49577200545  126.068  0.01386  -144.099
# 9.0  0.06131  -22.3  0.494917715967  50.842  0.01594  92.681
# 10.0  0.06511  -62.616  0.494305565147  -24.709  0.03062  17.211
# 11.0  0.04921  -103.35  0.494281663932  -100.686  0.05483  -59.794
# 12.0  0.02145  -171.123  0.494669347654  -177.233  0.07596  -144.184
# 13.0  0.044  57.205  0.494536669822  105.553  0.08221  128.684
# 14.0  0.10378  9.89  0.491895104114  27.725  0.07161  49.018
# 15.0  0.15386  -32.977  0.49188660946  -50.4  0.05907  -15.254
# ...
