# %%
from pyMeasure import *
# Out:
# Importing pyMeasure, this should take roughly 30 seconds
# The module smithplot was not found,please put it on the python path
# The module smithplot was not found,please put it on the python path

# %%
multiline_s1p_1=SNP(r"C:\Share\7mm\7mm\DUT\SM_Multiline.s1p")

# %%
multiline_s1p_1.show();

# %%
multiline_s1p_2=SNP(r"C:\Share\7mm\7mm\DUT\SM_Multiline_S2P.s1p")

# %%
multiline_s1p_2.show();
